# %% [markdown]
# Installations

# %%
import pandas as pd
import pytz
import re
import unicodedata
import nltk
import json
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from scipy.sparse import csr_matrix
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\fatim\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\fatim\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fatim\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# commnets

# %%
comments = pd.read_csv('instagram_comments.csv')
data = comments.loc[:,['post_id','created_at','username','text','parent_comment_id']]
data
# Out:
#            post_id  created_at          username  \
# 0      DQ51a5oEw2y  1762841875          heframid
# 1      DQ51a5oEw2y  1762844716  pdamsuryasembada
# 2      DQ51a5oEw2y  1762868957     kharistiano28
# 3      DQ51a5oEw2y  1762904139  pdamsuryasembada
# 4      DQ5v5UsE4As  1762834417    mhmdrizkyy12._
# ...            ...         ...               ...
# 27651  Czvi08FPNgg  1700223629  pdamsuryasembada
# 27652  Czvi08FPNgg  1700223639  pdamsuryasembada
# 27653  Czvi08FPNgg  1700223644  pdamsuryasembada
# 27654  Czvi08FPNgg  1700223839  pdamsuryasembada
# 27655  Czvi08FPNgg  1700223851  pdamsuryasembada
#
#                                                     text  parent_comment_id
# 0      Selamat ulang tahun ke-36 Harian Surya! 🎉 Semo...                NaN
# 1      @heframid Terima kasih Heframid. Semoga sukses...                NaN
# 2      👏👏👏 selalu menjalin kerjasama yg baik dgn medi...                NaN
# 3      @kharistiano28 terima kasih Bpk Kharistiano at...                NaN
# 4                  Selamatt dan semangattt indonesiaku😍🔥                NaN
# ...                                                  ...                ...
# 27651  @pratyaharasamadhi selamat malam pak mhn infor...                NaN
# 27652  @hellow_vee92 Selamat malam pak/bu, mohon maaf...                NaN
# 27653  @hellow_vee92 Selamat malam pak/bu, mohon maaf...                NaN
# 27654  @vii.4dity Selamat malam pak/bu, mohon maaf at...                NaN
# 27655  @insomnila Selamat malam pak/bu, mohon maaf at...                NaN
#
# [27656 rows x 5 columns]

# %% [markdown]
# Drop empty comments
# Remove comments from pdamsuryasembada
# Change date from epoch miliseconds
# Remove taggings from comments

# %%
data = data[data['username'].str.contains('pdamsuryasembada') == False]

data = data.drop_duplicates(subset=['text'])

local_timezone = pytz.timezone('Asia/Jakarta')
data['created_at'] = pd.to_datetime(data['created_at'], unit='s')
data['created_at'] = data['created_at'].dt.tz_localize('UTC').dt.tz_convert(local_timezone)
data['created_at'] = data['created_at'].dt.strftime('%Y-%m-%d %H:%M:%S %Z')

def remove_tags(text):
    if not isinstance(text, str):
        return ""
    return re.sub(r'@\w[\w\.]*', '', text).strip()

data['text'] = data['text'].apply(remove_tags)

data = data.dropna(subset=["text"])
data = data[data["text"].astype(str).str.strip() != ""]

# %% [markdown]
# cleaning

# %%
PUNCT_TO_REMOVE = "!#$%&()*+,./:;<=>@[\\]^_{|}~`"
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

data["text"] = data["text"].apply(lambda text: remove_punctuation(text))

def remove_emojis(text):
    """Removes standard unicode emojis from the text."""
    if not isinstance(text, str):
        return text

    emoji_pattern = re.compile(
        "["                     
        u"\U0001F600-\U0001F64F"
        u"\U0001F300-\U0001F5FF"
        u"\U0001F680-\U0001F6FF"
        u"\U0001F1E0-\U0001F1FF"
        u"\U0001F700-\U0001F77F"
        u"\U0001F780-\U0001F7FF"
        u"\U0001F800-\U0001F8FF"
        u"\U0001F900-\U0001F9FF"
        u"\U0001FA70-\U0001FAFF"
        u"\u2600-\u26FF"
        u"\u2700-\u27BF"
        u"\ufe0f"
        "]+",
        flags=re.UNICODE,
    )

    return emoji_pattern.sub(r'', text)

data['text'] = data['text'].apply(remove_emojis)
data['text'] = data['text'].str.strip()

def normalize_fancy_unicode(text):
    if not isinstance(text, str):
        return text

    normalized = unicodedata.normalize("NFKD", text)

    cleaned = "".join(
        ch for ch in normalized
        if not unicodedata.combining(ch)
    )
    return cleaned

data["text"] = data["text"].apply(normalize_fancy_unicode)

data = data.dropna(subset=["text"])
data = data[data["text"].astype(str).str.strip() != ""]

# %% [markdown]
# case folding

# %%
data["text"] = data["text"].str.lower()
data_comments = data["text"]

# %% [markdown]
# tokem

# %%
data['text'] = data['text'].astype(str).apply(word_tokenize)

# %%
def is_all_numbers(tokens):
    return all(re.fullmatch(r'\d+', tok) for tok in tokens)

data = data[~data['text'].apply(is_all_numbers)]


def normalize_mixed_number_token(token):
    if re.fullmatch(r'\d+', token):
        return "<num>"
    
    parts = re.findall(r'\d+|[a-zA-Z]+', token)

    if len(parts) == 1:
        return token

    parts = ["<num>" if p.isdigit() else p for p in parts]

    return " ".join(parts)


def normalize_tokens(token_list):
    normalized = []
    for tok in token_list:
        if tok.isdigit():
            normalized.append("<num>")
        elif re.search(r'\d', tok):
            normalized.append(normalize_mixed_number_token(tok))
        else:
            normalized.append(tok)
    return normalized

data["text"] = data["text"].apply(normalize_tokens)

# %%
data_partial = data.copy()
data_partial.to_csv('all_tokenized_v3.csv', index=False)
data_partial
# Out:
#            post_id               created_at           username  \
# 0      DQ51a5oEw2y  2025-11-11 13:17:55 WIB           heframid
# 2      DQ51a5oEw2y  2025-11-11 20:49:17 WIB      kharistiano28
# 4      DQ5v5UsE4As  2025-11-11 11:13:37 WIB     mhmdrizkyy12._
# 6      DQ5ldh8E_V7  2025-11-11 09:48:57 WIB         panggilnaw
# 9      DQ6J9gWE8rk  2025-11-11 16:04:18 WIB         baang_aziz
# ...            ...                      ...                ...
# 27646  Czvi08FPNgg  2023-11-17 17:26:00 WIB  pratyaharasamadhi
# 27647  Czvi08FPNgg  2023-11-17 17:42:18 WIB       bapakduaanak
# 27648  Czvi08FPNgg  2023-11-17 17:43:46 WIB            qenndra
# 27649  Czvi08FPNgg  2023-11-17 17:46:33 WIB          insomnila
# 27650  Czvi08FPNgg  2023-11-17 18:32:47 WIB          vii.gsrnv
#
#                                                     text  parent_comment_id
# 0      [selamat, ulang, tahun, ke <num>, harian, sury...                NaN
# 2      [selalu, menjalin, kerjasama, yg, baik, dgn, m...                NaN
# 4               [selamatt, dan, semangattt, indonesiaku]                NaN
# 6                             [dm, ku, ga, dibales, kak]                NaN
# 9                           [salam, buat, tim, spi, min]                NaN
# ...                                                  ...                ...
# 27646  [ancen, tumanbanyu, mati, ra, kondo <num>, dis...                NaN
# 27647  [sak, jane, laporane, wong <num>, iki, bener <...                NaN
# 27648  [kebiasaan, pdam, klo, mati, gk, woro <num>, d...                NaN
# 27649       [sudah, lapor, tapi, belum, nyala, seharian]                NaN
# 27650  [min, kok, durung, ono, update, info, e, wes, ...                NaN
#
# [16199 rows x 5 columns]

# %% [markdown]
# formalize

# %%
with open("dictionary/dict_template3_doneig.json", "r", encoding="utf-8") as f:
    formal_dict3 = json.load(f)

with open("dictionary/dict4.json", "r", encoding="utf-8") as f:
    formal_dict4 = json.load(f)

formal_dict = {**formal_dict3, **formal_dict4}

def apply_formalization(tokens, formal_dict):
    
    new_tokens = []
    for tok in tokens:
        if tok in formal_dict:
            replacement = formal_dict[tok]
            new_tokens.extend(replacement.split())
            # new_tokens.append(formal_dict[tok]) 
        else:
            new_tokens.append(tok)
    return new_tokens

data_partial["text"] = data_partial["text"].apply(lambda tokens: apply_formalization(tokens, formal_dict))

# %%
data_partial
# Out:
#            post_id               created_at           username  \
# 0      DQ51a5oEw2y  2025-11-11 13:17:55 WIB           heframid
# 2      DQ51a5oEw2y  2025-11-11 20:49:17 WIB      kharistiano28
# 4      DQ5v5UsE4As  2025-11-11 11:13:37 WIB     mhmdrizkyy12._
# 6      DQ5ldh8E_V7  2025-11-11 09:48:57 WIB         panggilnaw
# 9      DQ6J9gWE8rk  2025-11-11 16:04:18 WIB         baang_aziz
# ...            ...                      ...                ...
# 27646  Czvi08FPNgg  2023-11-17 17:26:00 WIB  pratyaharasamadhi
# 27647  Czvi08FPNgg  2023-11-17 17:42:18 WIB       bapakduaanak
# 27648  Czvi08FPNgg  2023-11-17 17:43:46 WIB            qenndra
# 27649  Czvi08FPNgg  2023-11-17 17:46:33 WIB          insomnila
# 27650  Czvi08FPNgg  2023-11-17 18:32:47 WIB          vii.gsrnv
#
#                                                     text  parent_comment_id
# 0      [selamat, ulang, tahun, ke <num>, harian, sury...                NaN
# 2      [selalu, menjalin, kerjasama, yg, baik, dgn, m...                NaN
# 4                    [selamat, dan, semangat, indonesia]                NaN
# 6                               [dm, ku, ga, balas, kak]                NaN
# 9                           [salam, buat, tim, spi, min]                NaN
# ...                                                  ...                ...
# 27646  [ancen, tuman, air, mati, ra, bilang, panas, n...                NaN
# 27647  [sak, seharusnya, lapor, iki, benar-benar, di,...                NaN
# 27648  [kebiasaan, pdam, klo, mati, gk, pengumuman, d...                NaN
# 27649       [sudah, lapor, tapi, belum, nyala, seharian]                NaN
# 27650  [min, kok, belum, ono, pembaruan, informasi, w...                NaN
#
# [16199 rows x 5 columns]

# %% [markdown]
# delete stopwor

# %%
with open('stopwords_v3 dg air.txt', 'r', encoding='utf-8') as f:
    custom_stopwords = set([line.strip() for line in f if line.strip()])

def remove_stopwords(tokens, stopword_set):
    return [tok for tok in tokens if tok not in stopword_set and tok.strip() != ""]

data_partial["text"] = data_partial["text"].apply(lambda tokens: remove_stopwords(tokens, custom_stopwords))

# %% [markdown]
# stemmming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.Stemmer.Stemmer import Stemmer
from Sastrawi.Stemmer.CachedStemmer import CachedStemmer
from Sastrawi.Stemmer.Cache.ArrayCache import ArrayCache
from Sastrawi.Dictionary.ArrayDictionary import ArrayDictionary

PROTECTED_WORDS = [
    'sememi',
]

factory = StemmerFactory()
base_words = factory.get_words_from_file()
combined_words = list(set(base_words + PROTECTED_WORDS))
custom_dict = ArrayDictionary(combined_words)
stemmer = CachedStemmer(ArrayCache(), Stemmer(custom_dict))

def stem_tokens(tokens):
    if not isinstance(tokens, list):
        return tokens
    return [stemmer.stem(tok) for tok in tokens]

data_partial["text"] = data_partial["text"].apply(stem_tokens)

# %%
data_partial.to_csv("stemmed_all_v5.csv", index=False)

# %%
comments = pd.read_csv('stemmed_all_v5.csv')
data_partial = comments.loc[:,['post_id','created_at','username','text']]
data_partial = data_partial[(data_partial['created_at'] > '2025-10-01') & (data_partial['created_at'] < '2025-11-01')]
import ast

data_partial['text'] = data_partial['text'].apply(ast.literal_eval)
data_partial
# Out:
#           post_id               created_at        username  \
# 10    DPiRgn6k9BI  2025-10-29 23:44:51 WIB      n_aiiniiii
# 11    DPiRgn6k9BI  2025-10-30 05:38:39 WIB  raymundus_aryo
# 12    DPiRgn6k9BI  2025-10-31 04:47:10 WIB       opera8176
# 13    DPiRgn6k9BI  2025-10-31 10:05:24 WIB     matokebenny
# 14    DPiRgn6k9BI  2025-10-31 10:06:07 WIB     matokebenny
# ...           ...                      ...             ...
# 9760  C8jD4uDP9Bt  2025-10-16 01:37:13 WIB    mamaerisma30
# 9761  C8jD4uDP9Bt  2025-10-23 06:20:37 WIB  babyjotuhumena
# 9762  C8jD4uDP9Bt  2025-10-25 14:55:57 WIB       melongrus
# 9763  C8jD4uDP9Bt  2025-10-30 14:25:29 WIB  moh.asyari3112
# 9764  C8jD4uDP9Bt  2025-10-31 11:07:28 WIB    mainhati2022
#
#                                                    text
# 10                         [paham, harga, pasang, pdam]
# 11                                               [rame]
# 12                          [pdam, jalan, gresik, mati]
# 13    [tugas, wilayah, ploso, timur, kali, cek, prem...
# 14      [kali, kirim, komplain, langsung, pecat, tugas]
# ...                                                 ...
# 9760  [pdam, bikin, hidup, susah, masak, begadang, l...
# 9761  [pdam, hebat, kl, ada, lambat, bayar, cepat, p...
# 9762    [wilayah, lendang, besok, kemaren, nyala, mati]
# 9763                            [wilayah, lampung, adu]
# 9764             [pdam, prigen, pasuruan, jatim, benah]
#
# [1177 rows x 4 columns]

# %% [markdown]
# tf(no IDF ig)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
data_partial['processed_text'] = data_partial['text'].apply(
    lambda tokens: " ".join(tokens)
)
# data_partial['processed_text'] = data_partial['text'].apply(lambda tokens: " ".join(tokens))
data_partial = data_partial[data_partial['processed_text'].str.strip() != ""]
vectorizer = TfidfVectorizer(
    tokenizer=str.split,
    ngram_range=(1,1),
    min_df=0.0,
    max_df=0.8,
    use_idf=False,
    norm=None
)

vectors = vectorizer.fit_transform(data_partial['processed_text'])
feature_names = vectorizer.get_feature_names_out()
vectors_dense = vectors.toarray()
# Out:
# d:\Kuliah\PA\pdam-scraper\scrape_instagram\venv\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
print(f"Vector shape: {vectors.shape}")
print(f"nonzero: {vectors.nnz}")
row = vectors[0]
indices = row.indices
values = row.data

for i, v in zip(indices, values):
    print(feature_names[i], v)
# Out:
# Vector shape: (1128, 1201)
# nonzero: 6063
# paham 1.0
# harga 1.0
# pasang 1.0
# pdam 1.0

# %% [markdown]
# ### Scenarios
# There will be three different scenarios of vector dataset that will have its clustering runs:
# 1. Direct TF output
# 2. Threshold
# 3. Binary turned values
# 4. Threshold + Binary

# %% [markdown]
# #### Scenario 1

# %%
vectors = vectorizer.fit_transform(data_partial['processed_text'])
feature_names = vectorizer.get_feature_names_out()
vectors_dense = vectors.toarray()

vectors_dense_old = vectors_dense.copy()
df_old = pd.DataFrame(vectors_dense_old, columns=feature_names)
df_old.insert(0, 'comment', data_partial['processed_text'].values)
df_old.to_csv("tf_before_normalization.csv", index=False)
print(f"Old vector shape: {vectors_dense_old.shape}")
# Out:
# Old vector shape: (1128, 1201)

# %% [markdown]
# #### Scenario 2
# *Threshold*
# 1. find the greatest valued feature pof each comment
# 2. half the value and use it as treshold for that comment
# 3. for any feature with a value in that comment, if it is less than half of it, then set it as zero

# %%
vectors_scene_2 = vectors_dense.copy()

for i in range(vectors_scene_2.shape[0]):
    row = vectors_scene_2[i]
    max_val = row.max()

    if max_val == 0:
        continue

    threshold = max_val / 2
    vectors_scene_2[i] = np.where(row >= threshold, row, 0.0)

non_zero_cols = np.any(vectors_scene_2 != 0, axis=0)
vectors_scene_2 = vectors_scene_2[:, non_zero_cols]
feature_names_scene_2 = feature_names[non_zero_cols]

print(f"New vector shape: {vectors_scene_2.shape}")
print(f"Features removed: {vectors_dense.shape[1] - vectors_scene_2.shape[1]}")

df_new2 = pd.DataFrame(vectors_scene_2, columns=feature_names_scene_2)
df_new2.insert(0, 'comment', data_partial['processed_text'].values)
df_new2.to_csv("tf_after_threshold.csv", index=False)
# Out:
# New vector shape: (1128, 1123)
# Features removed: 78

# %% [markdown]
# #### Scenario 3
# *Binary turned values*
# 1. for all feature with anon-zero value, ground them all to one
# 2. do this for all comments

# %%
vectors_scene_3 = (vectors_dense > 0).astype(int)
feature_names_scene_3 = feature_names
df_new_3 = pd.DataFrame(vectors_scene_3, columns=feature_names_scene_3)
df_new_3.insert(0, 'comment', data_partial['processed_text'].values)
df_new_3.to_csv("tf_after_binary.csv", index=False)

# %% [markdown]
# #### Scenario 4
# *Threshold + Binary*

# %%
vectors_scene_4 = vectors_dense.copy()

for i in range(vectors_scene_4.shape[0]):
    row = vectors_scene_4[i]
    max_val = row.max()
    if max_val == 0:
        continue
    threshold = max_val / 2
    vectors_scene_4[i] = np.where(row >= threshold, row, 0.0)

non_zero_cols = np.any(vectors_scene_4 != 0, axis=0)
vectors_scene_4 = vectors_scene_4[:, non_zero_cols]
feature_names_scene_4 = feature_names[non_zero_cols]

vectors_scene_4 = (vectors_scene_4 > 0).astype(int)

print(f"New vector shape: {vectors_scene_4.shape}")
print(f"Features removed: {vectors_dense.shape[1] - vectors_scene_4.shape[1]}")

df_new4 = pd.DataFrame(vectors_scene_4, columns=feature_names_scene_4)
df_new4.insert(0, 'comment', data_partial['processed_text'].values)
df_new4.to_csv("tf_after_threshold_binary.csv", index=False)
# Out:
# New vector shape: (1128, 1123)
# Features removed: 78

# %% [markdown]
# Attempt at valley tracing bruv

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

VERSIONS = {
    "Scenario 1 (Direct TF Results)" : vectors_dense_old,
    "Scenario 2 (Threshold)":   vectors_scene_2,
    "Scenario 3 (Binary)":    vectors_scene_3,
    "Scenario 4 (Threshold + Binary)" : vectors_scene_4,
}

LINKAGE_METHODS = ['centroid', 'single', 'complete', 'average']

v_results = {}

for method in LINKAGE_METHODS:
    for ver_name, vec in VERSIONS.items():
        run_key = f"[{method.upper()}] {ver_name}"

        print(f"\n{'='*60}")
        print(f"Linkage: {method}  |  Scenario: {ver_name}")
        print(f"Shape: {vec.shape}")
        print('-'*60)

        N = vec.shape[0] - 1
        Z = linkage(vec, method=method, metric='euclidean')
        k_list = list(range(N, 1, -1))
        grand_mean = vec.mean(axis=0)

        sil         = []
        vw_list     = []
        vb_list     = []
        v_ratio     = []
        valley_k    = []
        valley_diff = []

        for k in k_list:
            labels          = fcluster(Z, t=k, criterion='maxclust')
            unique_clusters = np.unique(labels)

            delta_within  = 0.0
            delta_between = 0.0

            for cid in unique_clusters:
                pts = vec[labels == cid]
                ni  = pts.shape[0]
                if ni <= 1:
                    continue
                centroid  = pts.mean(axis=0)
                delta_sq  = np.sum(np.linalg.norm(pts - centroid, axis=1) ** 2) / (ni - 1)
                delta_within  += (ni - 1) * delta_sq
                delta_between += ni * np.linalg.norm(centroid - grand_mean) ** 2

            vw2 = delta_within  / (N - k) if (N - k) > 0 else np.nan
            vb2 = delta_between / (k - 1) if (k - 1) > 0 else np.nan
            vw_list.append(vw2)
            vb_list.append(vb2)
            v_ratio.append((vw2 / vb2) * 100 if (vb2 and vb2 > 0) else np.nan)

            sc = (silhouette_score(vec, labels, metric='euclidean')
                  if len(unique_clusters) >= 2 else np.nan)
            sil.append(sc)

        vw_list = np.array(vw_list)
        vb_list = np.array(vb_list)
        v_ratio = np.array(v_ratio)
        sil     = np.array(sil)

        # V-Ratio
        first    = np.diff(v_ratio)
        second   = np.diff(first)
        idx_curv = np.nanargmax(np.abs(second))
        k_curv   = k_list[idx_curv + 2]

        # Sil
        valid_idx = np.where(~np.isnan(sil))[0]
        k_sil     = k_list[valid_idx[np.nanargmax(sil[valid_idx])]] if len(valid_idx) else None

        # Valley-tracing
        for i in range(1, len(v_ratio) - 1):
            prev = v_ratio[i - 1]
            curr = v_ratio[i]
            nxt  = v_ratio[i + 1]
            if np.isnan(prev) or np.isnan(curr) or np.isnan(nxt):
                continue
            if prev >= curr and nxt > curr:
                valley_k.append(k_list[i])
                partial_diff = (prev + nxt) - (2 * curr)
                valley_diff.append(partial_diff)

        print("Valley-tracing candidate k values:", valley_k)

        # Accu
        max_diff = None
        max_k    = None
        if valley_k:
            paired   = sorted(zip(valley_diff, valley_k), reverse=True)
            max_diff = paired[0][0]
            max_k    = paired[0][1]

            if len(paired) >= 2:
                second_diff = paired[1][0]
                second_k    = paired[1][1]
                accuracy    = max_diff / second_diff if second_diff != 0 else float('inf')
                print(f"Best k by valley-tracing:  {max_k}")
                print(f"k Closest Value to max ∂:  {second_k}")
                print(f"Max ∂:                     {max_diff:.4f}")
                print(f"Second Max ∂:              {second_diff:.4f}")
                print(f"Acuuracy:              {accuracy:.4f}")
            else:
                print(f"Only one valley found — k: {max_k}, ∂: {max_diff:.4f}") #gk bisa uji akurasi

        v_results[run_key] = {
            'method'     : method,
            'scenario'   : ver_name,
            'Z'          : Z,
            'vec'        : vec,
            'k_list'     : k_list,
            'vw_list'    : vw_list,
            'vb_list'    : vb_list,
            'v_ratio'    : v_ratio,
            'sil'        : sil,
            'k_curv'     : k_curv,
            'k_sil'      : k_sil,
            'valley_k'   : valley_k,
            'valley_diff': max_diff,
            'best_k'     : max_k,
        }
# Out:
# ============================================================
# Linkage: centroid  |  Scenario: Scenario 1 (Direct TF Results)
# Shape: (1128, 1201)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1021, 964, 928, 926, 922, 912, 909, 906, 896, 894, 890, 888, 823, 819, 785, 780, 778, 776, 774, 743, 740, 735, 728, 726, 723, 716, 711, 704, 700, 662, 658, 656, 654, 651, 649, 644, 639, 636, 633, 621, 618, 609, 605, 601, 598, 594, 590, 586, 581, 577, 575, 571, 567, 558, 550, 546, 528, 524, 516, 513, 507, 502, 500, 498, 496, 494, 489, 486, 482, 478, 468, 463, 460, 457, 449, 442, 431, 426, 424, 422, 415, 402, 399, 384, 377, 354, 346, 317, 315, 306, 300, 298, 295, 290, 280, 269, 259, 252, 243, 199, 162, 160, 156, 91, 80, 18, 15, 11, 7]
# Best k by valley-tracing:  18
# k Closest Value to max ∂:  7
# Max ∂:                     4670.4140
# Second Max ∂:              942.3824
# Acuuracy:              4.9560
#
# ============================================================
# Linkage: centroid  |  Scenario: Scenario 2 (Threshold)
# Shape: (1128, 1123)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1017, 959, 923, 921, 917, 907, 901, 891, 889, 885, 883, 818, 814, 780, 775, 773, 771, 769, 738, 735, 730, 723, 721, 718, 711, 706, 698, 694, 657, 653, 651, 649, 646, 644, 639, 634, 631, 628, 616, 613, 604, 600, 597, 595, 592, 588, 584, 580, 574, 570, 567, 563, 557, 553, 548, 543, 524, 521, 518, 515, 509, 506, 501, 497, 494, 492, 490, 488, 486, 484, 478, 475, 472, 470, 460, 457, 453, 448, 436, 434, 432, 430, 426, 408, 396, 386, 380, 372, 368, 364, 354, 342, 335, 324, 310, 308, 306, 299, 289, 283, 258, 219, 166, 105, 97, 62, 40, 34, 31, 23, 18, 15, 13, 11, 6, 3]
# Best k by valley-tracing:  40
# k Closest Value to max ∂:  6
# Max ∂:                     8471.1834
# Second Max ∂:              1412.9101
# Acuuracy:              5.9956
#
# ============================================================
# Linkage: centroid  |  Scenario: Scenario 3 (Binary)
# Shape: (1128, 1201)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1016, 957, 919, 917, 913, 904, 898, 887, 884, 880, 810, 766, 761, 759, 757, 755, 753, 726, 724, 720, 717, 712, 710, 706, 699, 692, 688, 686, 683, 640, 637, 635, 631, 628, 626, 622, 619, 616, 611, 609, 607, 592, 589, 578, 574, 570, 567, 565, 563, 561, 559, 557, 554, 549, 546, 543, 541, 532, 530, 527, 524, 521, 519, 516, 495, 493, 488, 480, 475, 473, 470, 465, 459, 457, 455, 448, 442, 440, 436, 432, 429, 423, 420, 417, 413, 407, 402, 400, 398, 395, 387, 385, 381, 379, 377, 367, 360, 357, 354, 351, 341, 337, 333, 329, 324, 316, 314, 302, 300, 298, 282, 278, 271, 268, 265, 262, 254, 245, 235, 213, 205, 201, 170, 49, 32, 22, 14, 9, 5]
# Best k by valley-tracing:  32
# k Closest Value to max ∂:  5
# Max ∂:                     8461.7733
# Second Max ∂:              1881.3898
# Acuuracy:              4.4976
#
# ============================================================
# Linkage: centroid  |  Scenario: Scenario 4 (Threshold + Binary)
# Shape: (1128, 1123)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1009, 945, 927, 906, 903, 899, 887, 882, 878, 865, 861, 856, 781, 738, 733, 731, 729, 726, 699, 693, 689, 684, 680, 677, 668, 665, 662, 659, 655, 653, 607, 602, 600, 590, 587, 583, 579, 576, 574, 571, 558, 556, 552, 543, 540, 537, 532, 530, 527, 525, 520, 517, 514, 511, 507, 499, 497, 494, 491, 489, 487, 485, 483, 481, 478, 462, 456, 453, 450, 439, 437, 434, 432, 430, 421, 414, 409, 406, 393, 387, 384, 375, 371, 369, 364, 360, 358, 348, 341, 339, 337, 322, 300, 296, 292, 289, 285, 277, 275, 261, 250, 240, 234, 229, 220, 218, 215, 209, 207, 205, 203, 200, 177, 172, 170, 166, 163, 159, 26, 19, 15, 8, 5]
# Best k by valley-tracing:  26
# k Closest Value to max ∂:  177
# Max ∂:                     13261.1524
# Second Max ∂:              4415.0035
# Acuuracy:              3.0037
#
# ============================================================
# Linkage: single  |  Scenario: Scenario 1 (Direct TF Results)
# Shape: (1128, 1201)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1021, 858, 667, 491, 380, 307, 242, 203, 169, 124, 107, 94, 81, 71, 66, 49, 40, 27, 25, 23, 21, 13, 7]
# Best k by valley-tracing:  27
# k Closest Value to max ∂:  21
# Max ∂:                     4843.5831
# Second Max ∂:              3025.7777
# Acuuracy:              1.6008
#
# ============================================================
# Linkage: single  |  Scenario: Scenario 2 (Threshold)
# Shape: (1128, 1123)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1017, 853, 661, 485, 371, 292, 227, 150, 104, 88, 75, 64, 55, 51, 36, 31, 29, 23, 17, 12, 9, 5, 3]
# Best k by valley-tracing:  55
# k Closest Value to max ∂:  51
# Max ∂:                     7827.0367
# Second Max ∂:              6226.4728
# Acuuracy:              1.2571
#
# ============================================================
# Linkage: single  |  Scenario: Scenario 3 (Binary)
# Shape: (1128, 1201)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1016, 846, 639, 460, 345, 269, 203, 127, 101, 81, 64, 50, 39, 32, 26, 23, 19, 14, 11, 5]
# Best k by valley-tracing:  39
# k Closest Value to max ∂:  19
# Max ∂:                     10435.4318
# Second Max ∂:              4076.9934
# Acuuracy:              2.5596
#
# ============================================================
# Linkage: single  |  Scenario: Scenario 4 (Threshold + Binary)
# Shape: (1128, 1123)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1009, 822, 596, 416, 304, 226, 163, 92, 69, 51, 28, 19, 15, 12, 9, 7, 5]
# Best k by valley-tracing:  5
# k Closest Value to max ∂:  28
# Max ∂:                     48382.1414
# Second Max ∂:              22943.5924
# Acuuracy:              2.1087
#
# ============================================================
# Linkage: complete  |  Scenario: Scenario 1 (Direct TF Results)
# Shape: (1128, 1201)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1021, 963, 837, 756, 657, 584, 516, 465, 406, 374, 324, 297, 273, 243, 223, 205, 185, 171, 154, 146, 137, 126, 117, 109, 103, 99, 93, 86, 76, 67, 57, 53, 49, 46, 43, 37, 32, 27, 23, 19, 15, 11, 8, 5]
# Best k by valley-tracing:  963
# k Closest Value to max ∂:  1021
# Max ∂:                     86.5883
# Second Max ∂:              86.5580
# Acuuracy:              1.0004
#
# ============================================================
# Linkage: complete  |  Scenario: Scenario 2 (Threshold)
# Shape: (1128, 1123)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1017, 958, 832, 752, 649, 573, 506, 456, 394, 360, 310, 283, 260, 231, 211, 189, 171, 154, 139, 128, 117, 110, 103, 97, 91, 86, 69, 61, 56, 54, 52, 39, 30, 28, 26, 24, 18, 13, 10, 6, 3]
# Best k by valley-tracing:  3
# k Closest Value to max ∂:  958
# Max ∂:                     1593.4220
# Second Max ∂:              90.8073
# Acuuracy:              17.5473
#
# ============================================================
# Linkage: complete  |  Scenario: Scenario 3 (Binary)
# Shape: (1128, 1201)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1016, 957, 822, 739, 635, 557, 480, 432, 369, 328, 280, 251, 224, 199, 174, 155, 139, 130, 112, 99, 91, 81, 68, 60, 45, 41, 36, 27, 25, 23, 20, 18, 15, 13, 8, 5, 3]
# Best k by valley-tracing:  3
# k Closest Value to max ∂:  957
# Max ∂:                     15770.3594
# Second Max ∂:              96.0220
# Acuuracy:              164.2370
#
# ============================================================
# Linkage: complete  |  Scenario: Scenario 4 (Threshold + Binary)
# Shape: (1128, 1123)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1009, 945, 799, 713, 605, 525, 449, 396, 326, 291, 247, 217, 190, 165, 143, 120, 106, 92, 80, 69, 59, 54, 48, 37, 35, 29, 24, 13, 11, 9, 5, 3]
# Best k by valley-tracing:  3
# k Closest Value to max ∂:  945
# Max ∂:                     21868.9589
# Second Max ∂:              98.0253
# Acuuracy:              223.0951
#
# ============================================================
# Linkage: average  |  Scenario: Scenario 1 (Direct TF Results)
# Shape: (1128, 1201)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1021, 963, 951, 946, 939, 927, 920, 910, 907, 899, 890, 887, 884, 824, 800, 798, 796, 792, 785, 780, 775, 768, 763, 722, 720, 718, 712, 707, 698, 693, 684, 657, 653, 651, 616, 611, 608, 593, 591, 584, 580, 569, 543, 533, 525, 522, 518, 515, 513, 508, 499, 495, 493, 470, 462, 459, 454, 450, 443, 439, 435, 432, 428, 425, 412, 408, 403, 401, 398, 389, 380, 376, 358, 356, 353, 350, 345, 338, 334, 330, 326, 315, 301, 296, 290, 268, 266, 263, 256, 248, 244, 240, 236, 230, 227, 224, 220, 215, 213, 208, 204, 187, 185, 182, 174, 168, 162, 160, 146, 129, 127, 123, 114, 108, 103, 101, 88, 75, 65, 60, 57, 51, 16, 11, 7]
# Best k by valley-tracing:  16
# k Closest Value to max ∂:  7
# Max ∂:                     4634.2102
# Second Max ∂:              942.3824
# Acuuracy:              4.9175
#
# ============================================================
# Linkage: average  |  Scenario: Scenario 2 (Threshold)
# Shape: (1128, 1123)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1017, 958, 946, 941, 934, 922, 915, 905, 902, 894, 885, 882, 879, 876, 819, 795, 793, 791, 787, 780, 774, 769, 762, 757, 717, 715, 713, 707, 703, 693, 688, 679, 651, 647, 645, 608, 603, 600, 586, 584, 580, 576, 574, 571, 562, 534, 524, 517, 515, 512, 507, 504, 502, 497, 488, 484, 461, 455, 453, 450, 446, 444, 440, 433, 429, 427, 423, 413, 401, 398, 396, 394, 392, 390, 387, 385, 376, 367, 364, 345, 343, 340, 337, 335, 332, 328, 325, 321, 316, 314, 302, 288, 277, 266, 256, 250, 246, 236, 230, 224, 222, 216, 211, 207, 202, 199, 197, 194, 189, 167, 165, 159, 152, 146, 144, 134, 116, 112, 109, 101, 94, 87, 81, 74, 70, 68, 60, 56, 45, 31, 23, 21, 18, 15, 9, 6, 3]
# Best k by valley-tracing:  9
# k Closest Value to max ∂:  31
# Max ∂:                     10130.2120
# Second Max ∂:              8992.4864
# Acuuracy:              1.1265
#
# ============================================================
# Linkage: average  |  Scenario: Scenario 3 (Binary)
# Shape: (1128, 1201)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1016, 956, 944, 939, 933, 920, 912, 900, 897, 892, 884, 878, 873, 870, 867, 807, 786, 782, 780, 776, 772, 769, 764, 759, 757, 754, 745, 740, 702, 699, 695, 687, 685, 674, 670, 668, 660, 639, 637, 628, 605, 600, 598, 593, 573, 562, 559, 548, 514, 505, 501, 498, 496, 494, 491, 488, 483, 480, 465, 442, 437, 430, 420, 411, 403, 400, 398, 396, 393, 391, 374, 367, 360, 357, 355, 348, 342, 338, 336, 331, 329, 316, 311, 302, 300, 298, 296, 293, 288, 274, 266, 260, 256, 248, 244, 237, 224, 220, 217, 213, 209, 203, 198, 184, 177, 175, 171, 165, 147, 143, 138, 136, 124, 104, 93, 83, 67, 33, 22, 14, 9, 5]
# Best k by valley-tracing:  5
# k Closest Value to max ∂:  9
# Max ∂:                     1881.3898
# Second Max ∂:              1559.7095
# Acuuracy:              1.2062
#
# ============================================================
# Linkage: average  |  Scenario: Scenario 4 (Threshold + Binary)
# Shape: (1128, 1123)
# ------------------------------------------------------------
# Valley-tracing candidate k values: [1009, 942, 928, 924, 917, 902, 896, 883, 881, 873, 862, 858, 854, 850, 847, 784, 768, 761, 757, 751, 748, 744, 742, 740, 738, 723, 720, 680, 676, 674, 671, 665, 663, 651, 649, 647, 643, 640, 635, 613, 604, 573, 563, 560, 545, 543, 538, 532, 530, 527, 516, 486, 480, 475, 472, 464, 462, 452, 450, 448, 446, 434, 430, 404, 400, 396, 389, 387, 385, 375, 372, 369, 362, 359, 354, 340, 336, 333, 331, 327, 325, 321, 317, 314, 301, 296, 293, 279, 277, 275, 268, 263, 258, 252, 235, 226, 224, 222, 218, 213, 206, 190, 183, 180, 176, 174, 163, 142, 137, 134, 129, 115, 111, 105, 103, 91, 72, 61, 54, 16, 8, 5]
# Best k by valley-tracing:  16
# k Closest Value to max ∂:  5
# Max ∂:                     15705.9427
# Second Max ∂:              1435.0826
# Acuuracy:              10.9443

# %%
feature_map = {
    "Scenario 1 (Direct TF Results)" : feature_names,
    "Scenario 2 (Threshold)":   feature_names_scene_2,
    "Scenario 3 (Binary)":    feature_names_scene_3,
    "Scenario 4 (Threshold + Binary)" : feature_names_scene_4,
}

def display_culster_details(tfidf_matrix, feature_names, labels, k, ver_name=""):
    print(f"\n{'-'*30}")
    print(f"Cluster Details — {ver_name}  (k={k})")
    
    cluster_info = {}
    
    for cluster_id in range(1, k+1):
        indices = np.where(labels == cluster_id)[0]
        
        if len(indices) == 0:
            continue
        
        cluster_data = tfidf_matrix[indices]
        if hasattr(cluster_data, 'toarray'):
            cluster_data = cluster_data.toarray()
        cluster_mean = cluster_data.mean(axis=0)
        threshold = cluster_mean.max() / 2
        above_threshold = np.where(cluster_mean > threshold)[0]
        sorted_idx = above_threshold[np.argsort(-cluster_mean[above_threshold])]
        keywords = [(feature_names[i], cluster_mean[i]) for i in sorted_idx]
        
        cluster_info[cluster_id] = {
            'members': data_partial['processed_text'].iloc[indices].tolist(),
            'count': len(indices),
            'keywords': keywords
        }
    
    for cluster_id, info in cluster_info.items():
        print(f"\nCluster {cluster_id}  ({info['count']} members)")
        print(f"  Members: {info['members']}")
        kw_str = ", ".join([f"{w}({s:.3f})" for w, s in info['keywords'][:10]])
        print(f"  Keywords: {kw_str if kw_str else '—'}")
    
    return cluster_info


for ver_name, res in v_results.items():
    k_used = res.get('best_k') or res['k_curv']
    k_used = int(k_used)
    labels_opt = fcluster(res['Z'], t=k_used, criterion='maxclust')
    scenario = res['scenario']
    features = feature_map.get(scenario, feature_names)

    display_culster_details(
        tfidf_matrix=res['vec'],
        feature_names=features,
        labels=labels_opt,
        k=k_used,
        ver_name=ver_name
    )
# Out:
# ------------------------------
# Cluster Details — [CENTROID] Scenario 1 (Direct TF Results)  (k=18)
#
# Cluster 1  (2 members)
#   Members: ['aduh pdam gayungsari barat area resto kampung steak mati nyala nyala mati nyala ada rumah mati tidak bagi bingung tampung habis bantu pdam', 'aduh pdam gayungsari barat area resto kampung steak ada bingung tampung rumah habis mati nyala nyala mati nyala ada rumah mati tidak bagi bantu pdam']
#   Keywords: mati(3.000), nyala(3.000), pdam(2.000)
#
# Cluster 2  (1110 members)
#   Members: ['paham harga pasang pdam', 'rame', 'pdam jalan gresik mati', 'tugas wilayah ploso timur kali cek preman ketuk pagar ugal-ugalan kayu pentung preman pagar tetangga', 'kali kirim komplain langsung pecat tugas', 'pdam hati alir baik', 'kebraon susah aktivitas', 'laku', 'syarat lengkap proses pasang', 'karah mati ada pemberitahuan tayamum', 'aju tanggal september keluar rincian tanggal september bayar batas bayar smp oktober harga promo agustus smp september ada promo', 'dm', 'rungkut industri mati', 'pdam keruh', 'kertaja kecil tidak', 'karang menjangan susah bos', 'tagih pdam lonjak drastis', 'pdam wonorejo rungkut mati', 'adu gubris cs tugas mati hari meter bocor habis ganti meter masalah', 'informasi ganggu wilayah babat jerawat pondok benowo indah', 'lapor pdam gara-gara jumat malam nyala ak paksa tidur hawa panas badan lengket nyala langsung mandi isi bak cuci subuh ape tidur bos', 'baik nyala rutinitas pdam pekan nyala', 'jalan juwingan mati ada informasi mohon informasi mati', 'informasi tanggal promo', 'karah mati', 'ruwet bayar pasang bulan', 'daftar pasang pdam daftar', 'pdam normal minggu pagi nyala wonorejo manuk kulon', 'lidah kulon mati hari', 'ada baik mati malam', 'pdam baik keruh bau kayak bagus aju komplain cek bersih isi pagi bau keruh pdam adu tugas bosan rumah', 'kebraon mati', 'kebraon mati', 'mati pdam kebraon ad pemberitahuan', 'karah mati ada ap efek gorong-gorong bikin sedih masak minggu ganti wifi mati', 'aju tanggal september ada pasang ada pasang', 'tugas kumpul berkas info minggu pasang', 'kebraon mati', 'pagi daerah karah mati tidak ada pemberitahuan ada', 'mati', 'mati wisma pagesangan tidak ada pemberitahuan mati', 'simo tambaan barusan mertua tugas abal suruh ganti meter', 'meter ganti', 'tidak ada tugas cek meter salah langgan', 'mohon bantu pdam wilayah kebraon tidak alir tanggal malam pagi tidak ada kompensasi tangki', 'berangkat sekolah berangkat kerja pdam mati daerah pondok maritim lurah balas klumprik', 'daerah gading karya pagi mati sore mati', 'ulan', 'sore malam mati daerah komplek tni al juanda susah', 'keluar', 'komplek tni al juanda sore tidak ada sekolah kantor', 'kebraon mati tidak ada informasi sm tugas', 'tidak keluar mati tandon tip', 'pdam daerah jiwa mati', 'hubung telepon wib siang tidak ada tugas', 'senin tanggal oktober tugas pdam ganti meter ganti meter gerak kran tutup lokasi kedung baruk rungkut', 'ada tugas baik pipa bocor lokasi', 'pagi pdam pdam gayung kebonsari pagi tidak keluar alir siang mohon informasi bantu', 'kerja', 'jadwal catat mandiri tanggal ubah pikir pergi kota', 'telepon no sibuk', 'terang proses cepat kumpul berkas tanggal september ada pasang', 'kirim pesan', 'daftar daring via aplikasi tahap verifikasi pasang butuh', 'nomor antri mohon bantu', 'daerah jalan gresik mati pdam mohon tindak ada', 'pdam mati wilayah rumah pondok maritim ada pemberitahuan tidur mati anak kerja sekolah butuh mandi', 'pagi mati area wisma lidah kulon', 'nyala', 'nyala', 'admin area dupak keluar chat tangki ada respon', 'telepon call center respon adu rusa meter', 'ada', 'proyek', 'anjir', 'pdam jalan raya sambikerep mati', 'ada pemberitahuan antisipasi lupa tidak ada pemberitahuan', 'informasi', 'keren instalasi ipam ngagel', 'keren olah ipam ngagel', 'dang ipam ngagel keren', 'baik', 'perumda minum populer', 'maju layan', 'keren', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'lahir to be bangga besar as indonesia', 'alir semangat muda', 'sumpah pemuda', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'sumpah pemuda cermin berani anak bangsa satu tengah beda', 'rumah daerah ptc surabaya barat keruh kemaren', 'bagus', 'jambang mati sabtu siang nyala bayar', 'jambang nyala cm', 'medayu mati ada baik', 'sambikerep mati gada pemberitahuan', 'mati pagi mandi tayamum sambikerep', 'keluar nang sambikerep berangkat kerja mandi keluar', 'medok ayu mati', 'area medayu mati', 'nyala ada pemberitahuan status pdam ada pemberitahuan', 'bantu pipa sa ...
#   Keywords: mati(0.398)
#
# Cluster 3  (1 members)
#   Members: ['pagi malam nyala parah nyala malam tok pagi parah banget pagi nyala tetea kran buka ak isa masak mandi cuci bersih']
#   Keywords: nyala(3.000), pagi(3.000), malam(2.000), parah(2.000)
#
# Cluster 4  (1 members)
#   Members: ['barusan rumah aku tugas pdam tuju ganti meter pdam surat tugas beliau tidak foto orang kendara tidak surat tugas langsung pergi alas rumit bongkar']
#   Keywords: tugas(3.000), pdam(2.000), surat(2.000), tidak(2.000)
#
# Cluster 5  (1 members)
#   Members: ['pagi pdam kebraon gang sekolah mati baik gang tomat kebraon pagi mati debit kecil mohon ada baik wilayah pokok tekan kurang pagi mati']
#   Keywords: mati(3.000), pagi(3.000), gang(2.000), baik(2.000), kebraon(2.000)
#
# Cluster 6  (1 members)
#   Members: ['tidak keluar mati pagi subuh tu liat ada kerja bego gali situ gali area situ tutup gali tutup ada bocor mohon cek ada informasi pdam mati kejar produksi sulit']
#   Keywords: ada(3.000), gali(3.000), mati(2.000), situ(2.000), tutup(2.000)
#
# Cluster 7  (1 members)
#   Members: ['ada informasi ganggu mati pet ada informasi mati ualng ada informasi mati kadang besok kerja sekolah malam makan besok pagi mati pdam layan baik']
#   Keywords: mati(4.000), ada(3.000), informasi(3.000)
#
# Cluster 8  (1 members)
#   Members: ['rumah daerah muhammad mari bocor mari baik admin pagi awan malam mantap pagi nyala kran dapur tunggu awan admin nak dapur pompa admin tanda bocor admin']
#   Keywords: admin(4.000)
#
# Cluster 9  (1 members)
#   Members: ['ak telepon jawab lapor kait kerja telepon jawab templat warga pbi keluar malam khusus pakai pompa keluar tetea keluar bulan malam subuh nyala kemaren malam detik keluar']
#   Keywords: keluar(4.000), malam(3.000)
#
# Cluster 10  (1 members)
#   Members: ['pantau gorong-gorong daerah sumber laku ubah mati baik jaring informasi orang anggur pagi ate sambut kerja mati fungsi orang ikut akun erti informasi klarifikasi bukti slogan gerak cepat seng cepat seng informasi dadi klarifikasi bodoh']
#   Keywords: informasi(3.000), cepat(2.000), klarifikasi(2.000), mati(2.000), orang(2.000), seng(2.000)
#
# Cluster 11  (1 members)
#   Members: ['minggu tunggu keluar malam keluar tidur tunggu gilir bayar telat denda bantu keluar kerja pompa lelah listrik listrik subsidi listrik mandiri alias bayar keluar ky got hitam letek']
#   Keywords: keluar(4.000), listrik(3.000)
#
# Cluster 12  (1 members)
#   Members: ['merek pipa kualitas seng pakai bocor mati bayar mahal bolak mati minggu mati cuci seragam yak cak elus karo pikir tangki solusi pikir kudu kolektif rt pesan tangki wadah seng tandon coba pikir solusi']
#   Keywords: mati(3.000), pikir(3.000), seng(2.000), solusi(2.000), tangki(2.000)
#
# Cluster 13  (1 members)
#   Members: ['malam informasi alir rumah mati akibat pipa pdam buntu dampak kerja kotak culvert mulyosari lapor rabu malam jumat ada respon tugas pdam baik janji janji ada tugas hubung contoh pln depan langgan layan janji janji tidak baik jalan bhaskara no janji']
#   Keywords: janji(5.000)
#
# Cluster 14  (1 members)
#   Members: ['warga tinggal dinding tengah xi alami tidak senang pdam keluar butuh tidak keluar siang keluar malam contoh pagi minggu oktober cuci pakai keluar normal tengah giat cuci tidak alir pdam rumah sedot pompa tetangga rutin adu tugas tangan ada ubah bayar bulan rutin layan kecewa']
#   Keywords: keluar(4.000), tidak(3.000)
#
# Cluster 15  (1 members)
#   Members: ['informasi mepet malam tidur bangun bangun petang nyala kamar mandi keluar langsung pikir cek instagram pdam ada baik tagih ribu total juta ribu kondisi tidak nyala mati baik ulang mati rumah tandon sumur andal pdam sulit baik kali nama rugi bocor pipa tagih murah oke oke pakai tagih padan']
#   Keywords: baik(3.000), tagih(3.000), mati(2.000), bangun(2.000), nyala(2.000), oke(2.000), pdam(2.000), ribu(2.000)
#
# Cluster 16  (1 members)
#   Members: ['pekan pdam kunjung rumah istri tangan no surat tidak ada apa informasi janji to ganti meter has to be jadwal meter not until pekan no informasi layan mohon cek maksud jalan has tidak ada apa to do layan do butuh informasi mohon via messenger']
#   Keywords: informasi(3.000), to(3.000), do(2.000), ada(2.000), has(2.000), layan(2.000), meter(2.000), apa(2.000), mohon(2.000), no(2.000)
#
# Cluster 17  (1 members)
#   Members: ['usaha cepat kira tuntut pbi ku habis sengaja tidak isi perak pbi bening abis baik nyala butek super butek tuju ku habis tandon minggu pbi nyala bening minggu ada baik baik nyala bersih jernih baik nyala keruh kecil debit usaha kira']
#   Keywords: baik(4.000), nyala(4.000), pbi(3.000)
#
# Cluster 18  (1 members)
#   Members: ['cari solusi ulang ada pipa bocor pdam alangkah cari solusi bocor bocor baik cepat hambat aktivitas warga butuh pdam warga bayar bantu gratis tagih tidak murah bocor pipa cari solusi perintah tag ada peduli perintah ulang bagus ulang ada ubah baik']
#   Keywords: bocor(4.000), ada(3.000), cari(3.000), solusi(3.000), ulang(3.000)
#
# ------------------------------
# Cluster Details — [CENTROID] Scenario 2 (Threshold)  (k=40)
#
# Cluster 1  (2 members)
#   Members: ['aduh pdam gayungsari barat area resto kampung steak mati nyala nyala mati nyala ada rumah mati tidak bagi bingung tampung habis bantu pdam', 'aduh pdam gayungsari barat area resto kampung steak ada bingung tampung rumah habis mati nyala nyala mati nyala ada rumah mati tidak bagi bantu pdam']
#   Keywords: mati(3.000), nyala(3.000), pdam(2.000)
#
# Cluster 2  (1088 members)
#   Members: ['paham harga pasang pdam', 'rame', 'pdam jalan gresik mati', 'tugas wilayah ploso timur kali cek preman ketuk pagar ugal-ugalan kayu pentung preman pagar tetangga', 'kali kirim komplain langsung pecat tugas', 'pdam hati alir baik', 'kebraon susah aktivitas', 'laku', 'syarat lengkap proses pasang', 'karah mati ada pemberitahuan tayamum', 'dm', 'rungkut industri mati', 'pdam keruh', 'kertaja kecil tidak', 'karang menjangan susah bos', 'tagih pdam lonjak drastis', 'pdam wonorejo rungkut mati', 'adu gubris cs tugas mati hari meter bocor habis ganti meter masalah', 'informasi ganggu wilayah babat jerawat pondok benowo indah', 'baik nyala rutinitas pdam pekan nyala', 'jalan juwingan mati ada informasi mohon informasi mati', 'informasi tanggal promo', 'karah mati', 'ruwet bayar pasang bulan', 'daftar pasang pdam daftar', 'pdam normal minggu pagi nyala wonorejo manuk kulon', 'lidah kulon mati hari', 'ada baik mati malam', 'kebraon mati', 'kebraon mati', 'mati pdam kebraon ad pemberitahuan', 'karah mati ada ap efek gorong-gorong bikin sedih masak minggu ganti wifi mati', 'aju tanggal september ada pasang ada pasang', 'tugas kumpul berkas info minggu pasang', 'kebraon mati', 'pagi daerah karah mati tidak ada pemberitahuan ada', 'mati', 'mati wisma pagesangan tidak ada pemberitahuan mati', 'simo tambaan barusan mertua tugas abal suruh ganti meter', 'meter ganti', 'tidak ada tugas cek meter salah langgan', 'mohon bantu pdam wilayah kebraon tidak alir tanggal malam pagi tidak ada kompensasi tangki', 'berangkat sekolah berangkat kerja pdam mati daerah pondok maritim lurah balas klumprik', 'daerah gading karya pagi mati sore mati', 'ulan', 'sore malam mati daerah komplek tni al juanda susah', 'keluar', 'komplek tni al juanda sore tidak ada sekolah kantor', 'kebraon mati tidak ada informasi sm tugas', 'tidak keluar mati tandon tip', 'pdam daerah jiwa mati', 'hubung telepon wib siang tidak ada tugas', 'senin tanggal oktober tugas pdam ganti meter ganti meter gerak kran tutup lokasi kedung baruk rungkut', 'ada tugas baik pipa bocor lokasi', 'pagi pdam pdam gayung kebonsari pagi tidak keluar alir siang mohon informasi bantu', 'kerja', 'jadwal catat mandiri tanggal ubah pikir pergi kota', 'telepon no sibuk', 'terang proses cepat kumpul berkas tanggal september ada pasang', 'kirim pesan', 'daftar daring via aplikasi tahap verifikasi pasang butuh', 'nomor antri mohon bantu', 'daerah jalan gresik mati pdam mohon tindak ada', 'pdam mati wilayah rumah pondok maritim ada pemberitahuan tidur mati anak kerja sekolah butuh mandi', 'pagi mati area wisma lidah kulon', 'nyala', 'nyala', 'admin area dupak keluar chat tangki ada respon', 'telepon call center respon adu rusa meter', 'ada', 'proyek', 'anjir', 'pdam jalan raya sambikerep mati', 'ada pemberitahuan antisipasi lupa tidak ada pemberitahuan', 'informasi', 'keren instalasi ipam ngagel', 'keren olah ipam ngagel', 'dang ipam ngagel keren', 'baik', 'perumda minum populer', 'maju layan', 'keren', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'lahir to be bangga besar as indonesia', 'alir semangat muda', 'sumpah pemuda', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'sumpah pemuda cermin berani anak bangsa satu tengah beda', 'rumah daerah ptc surabaya barat keruh kemaren', 'bagus', 'jambang mati sabtu siang nyala bayar', 'jambang nyala cm', 'medayu mati ada baik', 'sambikerep mati gada pemberitahuan', 'mati pagi mandi tayamum sambikerep', 'keluar nang sambikerep berangkat kerja mandi keluar', 'medok ayu mati', 'area medayu mati', 'nyala ada pemberitahuan status pdam ada pemberitahuan', 'bantu pipa salur bocor habis giat warga bersih got hari lapor rabu tangan', 'medok ayu mati tindak dm instagram chat wa call center lambat respon', 'medayu utara minggu mati minggu mati ada pemberitahuan kaya tu ada kompensasi cape admin ada proyek kotak culvert mesti mati', 'nyala tidur tunggu nyala malam', 'nyala tengah malam lantai rumah lantai tempat kakak keluar', 'nyala kakak m ...
#   Keywords: mati(0.390)
#
# Cluster 3  (1 members)
#   Members: ['barusan rumah aku tugas pdam tuju ganti meter pdam surat tugas beliau tidak foto orang kendara tidak surat tugas langsung pergi alas rumit bongkar']
#   Keywords: tugas(3.000), pdam(2.000), surat(2.000), tidak(2.000)
#
# Cluster 4  (1 members)
#   Members: ['bu kayak gorong-gorong kerja area tanggal beres perhati ada proyek gali mesti bocor kayak paham situbada karingan pipa jarak']
#   Keywords: kayak(2.000)
#
# Cluster 5  (1 members)
#   Members: ['adu pdam cepat call center sibuk cis pdam surabaya proses meter putar kran mati call center cs cm bpk pdam mesti adu']
#   Keywords: pdam(3.000), adu(2.000), call(2.000), center(2.000)
#
# Cluster 6  (1 members)
#   Members: ['anak buang beli galon ada ge tandon cebok ge shalat butuh wudhu ra tau mandi awak lengket mok tayamum']
#   Keywords: ge(2.000)
#
# Cluster 7  (1 members)
#   Members: ['minggu jalan mati malam kadang siang daerah wisma pagesangan proyek kotak culvert proyek kotak culvert hati']
#   Keywords: culvert(2.000), kotak(2.000), proyek(2.000)
#
# Cluster 8  (1 members)
#   Members: ['lanjur tampung gang mati mati gang mati mati jan jan sulit tok']
#   Keywords: mati(4.000)
#
# Cluster 9  (1 members)
#   Members: ['pdam area lancar jernih normal warga senang bantu kawan pdam juang bantu atas keluh warga semangat']
#   Keywords: bantu(2.000), pdam(2.000), warga(2.000)
#
# Cluster 10  (1 members)
#   Members: ['lewat tidak cetak struk bayar cetak struk masuk menu tidak ada menu riwayat transaksi']
#   Keywords: cetak(2.000), menu(2.000), struk(2.000), tidak(2.000)
#
# Cluster 11  (1 members)
#   Members: ['wilayah bronggalan keluar da pagi sd malam sd tahun mohon solusi lapor tugas alir cek pdam surabaya perhati daerah lancar ada']
#   Keywords: sd(2.000)
#
# Cluster 12  (1 members)
#   Members: ['japri lapang langsung capek kotak culvert mohon bantu ikut cepet diare puyeng mati omset umkm dampak langgan rugi bayar tagih pdam dpt maksimal']
#   Keywords: bantu(1.000), bayar(1.000), capek(1.000), cepet(1.000), culvert(1.000), dampak(1.000), diare(1.000), dpt(1.000), ikut(1.000), japri(1.000)
#
# Cluster 13  (1 members)
#   Members: ['rumah griya surabaya asri gorong-gorong mati ape umbah umbah seragam pasang pikir ada pompa butek mati awak bayar duduk subsidi']
#   Keywords: mati(2.000), umbah(2.000)
#
# Cluster 14  (1 members)
#   Members: ['tindak pdam area pbi mati hari bulan kali baik rugi masyarakat butuh utama mati tidak warga tandon tidak warga sumur mati hari tindak']
#   Keywords: mati(3.000), hari(2.000), tidak(2.000), tindak(2.000), warga(2.000)
#
# Cluster 15  (1 members)
#   Members: ['pdam baik keruh bau kayak bagus aju komplain cek bersih isi pagi bau keruh pdam adu tugas bosan rumah']
#   Keywords: bau(2.000), keruh(2.000), pdam(2.000)
#
# Cluster 16  (1 members)
#   Members: ['pagi malam nyala parah nyala malam tok pagi parah banget pagi nyala tetea kran buka ak isa masak mandi cuci bersih']
#   Keywords: nyala(3.000), pagi(3.000), malam(2.000), parah(2.000)
#
# Cluster 17  (1 members)
#   Members: ['bicara gampang tampung tampung hujan musim kemarau kirim pasok kudu warga gampang pdam oh pdam tarif denda telat no']
#   Keywords: gampang(2.000), pdam(2.000), tampung(2.000)
#
# Cluster 18  (1 members)
#   Members: ['aju tanggal september keluar rincian tanggal september bayar batas bayar smp oktober harga promo agustus smp september ada promo']
#   Keywords: september(3.000), bayar(2.000), promo(2.000), smp(2.000), tanggal(2.000)
#
# Cluster 19  (1 members)
#   Members: ['pdam hormat mohon baik debit kali mati baik tidak keluar keluar bu bayang posisi tidak tandon ganggu aktivasi rumah tangga hari']
#   Keywords: baik(2.000), keluar(2.000), tidak(2.000)
#
# Cluster 20  (1 members)
#   Members: ['keluar humas ada baik sosialisasi sosial media ikut pdam sosialisasi dampak ksi solusi water tank komen sm tetangga jalan angkut orang tua mohon bijak']
#   Keywords: sosialisasi(2.000)
#
# Cluster 21  (1 members)
#   Members: ['malam informasi alir rumah mati akibat pipa pdam buntu dampak kerja kotak culvert mulyosari lapor rabu malam jumat ada respon tugas pdam baik janji janji ada tugas hubung contoh pln depan langgan layan janji janji tidak baik jalan bhaskara no janji']
#   Keywords: janji(5.000)
#
# Cluster 22  (1 members)
#   Members: ['lapor pdam gara-gara jumat malam nyala ak paksa tidur hawa panas badan lengket nyala langsung mandi isi bak cuci subuh ape tidur bos']
#   Keywords: nyala(2.000), tidur(2.000)
#
# Cluster 23  (1 members)
#   Members: ['pdam bikin hidup susah masak begadang lancar tidak lancar pdam bikin orang hidup orang susah']
#   Keywords: bikin(2.000), hidup(2.000), lancar(2.000), orang(2.000), pdam(2.000), susah(2.000)
#
# Cluster 24  (1 members)
#   Members: ['pagi pdam kebraon gang sekolah mati baik gang tomat kebraon pagi mati debit kecil mohon ada baik wilayah pokok tekan kurang pagi mati']
#   Keywords: mati(3.000), pagi(3.000), gang(2.000), baik(2.000), kebraon(2.000)
#
# Cluster 25  (1 members)
#   Members: ['pantau gorong-gorong daerah sumber laku ubah mati baik jaring informasi orang anggur pagi ate sambut kerja mati fungsi orang ikut akun erti informasi klarifikasi bukti slogan gerak cepat seng cepat seng informasi dadi klarifikasi bodoh']
#   Keywords: informasi(3.000), cepat(2.000), klarifikasi(2.000), mati(2.000), orang(2.000), seng(2.000)
#
# Cluster 26  (1 members)
#   Members: ['ki tanggal tanggal ra nyala ki uang habis beli galon tarik tagih tagih telat telat denda nyala kayak']
#   Keywords: ki(2.000), nyala(2.000), tagih(2.000), tanggal(2.000), telat(2.000)
#
# Cluster 27  (1 members)
#   Members: ['tidak keluar mati pagi subuh tu liat ada kerja bego gali situ gali area situ tutup gali tutup ada bocor mohon cek ada informasi pdam mati kejar produksi sulit']
#   Keywords: ada(3.000), gali(3.000), mati(2.000), situ(2.000), tutup(2.000)
#
# Cluster 28  (1 members)
#   Members: ['merek pipa kualitas seng pakai bocor mati bayar mahal bolak mati minggu mati cuci seragam yak cak elus karo pikir tangki solusi pikir kudu kolektif rt pesan tangki wadah seng tandon coba pikir solusi']
#   Keywords: mati(3.000), pikir(3.000), seng(2.000), solusi(2.000), tangki(2.000)
#
# Cluster 29  (1 members)
#   Members: ['proyek pemkot area bocor bego seberang alfamart kerja pegawai beda area sat set hati jarang ada bocor pipa titik mohon warga rugi tutup usaha omset parah']
#   Keywords: area(2.000), bocor(2.000)
#
# Cluster 30  (1 members)
#   Members: ['pdam hebat kl ada lambat bayar cepat putus alir langgan bikin langgan bingung dg alir ada pemberitahuan nomor warga taman telaga bodas karangrejo gajahmungkur semarang']
#   Keywords: ada(2.000), alir(2.000), langgan(2.000)
#
# Cluster 31  (1 members)
#   Members: ['benar pondok benowo indah hari pdam keluar coba cek baik sememi pagi coba nyala keluar mandi sakit sembuh krisis pondok benowo indah']
#   Keywords: benowo(2.000), coba(2.000), indah(2.000), keluar(2.000), pondok(2.000)
#
# Cluster 32  (1 members)
#   Members: ['ak telepon jawab lapor kait kerja telepon jawab templat warga pbi keluar malam khusus pakai pompa keluar tetea keluar bulan malam subuh nyala kemaren malam detik keluar']
#   Keywords: keluar(4.000), malam(3.000)
#
# Cluster 33  (1 members)
#   Members: ['minggu tunggu keluar malam keluar tidur tunggu gilir bayar telat denda bantu keluar kerja pompa lelah listrik listrik subsidi listrik mandiri alias bayar keluar ky got hitam letek']
#   Keywords: keluar(4.000), listrik(3.000)
#
# Cluster 34  (1 members)
#   Members: ['ada informasi ganggu mati pet ada informasi mati ualng ada informasi mati kadang besok kerja sekolah malam makan besok pagi mati pdam layan baik']
#   Keywords: mati(4.000), ada(3.000), informasi(3.000)
#
# Cluster 35  (1 members)
#   Members: ['rumah daerah muhammad mari bocor mari baik admin pagi awan malam mantap pagi nyala kran dapur tunggu awan admin nak dapur pompa admin tanda bocor admin']
#   Keywords: admin(4.000)
#
# Cluster 36  (1 members)
#   Members: ['informasi mepet malam tidur bangun bangun petang nyala kamar mandi keluar langsung pikir cek instagram pdam ada baik tagih ribu total juta ribu kondisi tidak nyala mati baik ulang mati rumah tandon sumur andal pdam sulit baik kali nama rugi bocor pipa tagih murah oke oke pakai tagih padan']
#   Keywords: baik(3.000), tagih(3.000), mati(2.000), bangun(2.000), nyala(2.000), oke(2.000), pdam(2.000), ribu(2.000)
#
# Cluster 37  (1 members)
#   Members: ['warga tinggal dinding tengah xi alami tidak senang pdam keluar butuh tidak keluar siang keluar malam contoh pagi minggu oktober cuci pakai keluar normal tengah giat cuci tidak alir pdam rumah sedot pompa tetangga rutin adu tugas tangan ada ubah bayar bulan rutin layan kecewa']
#   Keywords: keluar(4.000), tidak(3.000)
#
# Cluster 38  (1 members)
#   Members: ['pekan pdam kunjung rumah istri tangan no surat tidak ada apa informasi janji to ganti meter has to be jadwal meter not until pekan no informasi layan mohon cek maksud jalan has tidak ada apa to do layan do butuh informasi mohon via messenger']
#   Keywords: informasi(3.000), to(3.000), do(2.000), ada(2.000), has(2.000), layan(2.000), meter(2.000), apa(2.000), mohon(2.000), no(2.000)
#
# Cluster 39  (1 members)
#   Members: ['usaha cepat kira tuntut pbi ku habis sengaja tidak isi perak pbi bening abis baik nyala butek super butek tuju ku habis tandon minggu pbi nyala bening minggu ada baik baik nyala bersih jernih baik nyala keruh kecil debit usaha kira']
#   Keywords: baik(4.000), nyala(4.000), pbi(3.000)
#
# Cluster 40  (1 members)
#   Members: ['cari solusi ulang ada pipa bocor pdam alangkah cari solusi bocor bocor baik cepat hambat aktivitas warga butuh pdam warga bayar bantu gratis tagih tidak murah bocor pipa cari solusi perintah tag ada peduli perintah ulang bagus ulang ada ubah baik']
#   Keywords: bocor(4.000), ada(3.000), cari(3.000), solusi(3.000), ulang(3.000)
#
# ------------------------------
# Cluster Details — [CENTROID] Scenario 3 (Binary)  (k=32)
#
# Cluster 1  (2 members)
#   Members: ['aduh pdam gayungsari barat area resto kampung steak mati nyala nyala mati nyala ada rumah mati tidak bagi bingung tampung habis bantu pdam', 'aduh pdam gayungsari barat area resto kampung steak ada bingung tampung rumah habis mati nyala nyala mati nyala ada rumah mati tidak bagi bantu pdam']
#   Keywords: ada(1.000), aduh(1.000), area(1.000), bagi(1.000), bantu(1.000), barat(1.000), bingung(1.000), gayungsari(1.000), habis(1.000), kampung(1.000)
#
# Cluster 2  (1096 members)
#   Members: ['paham harga pasang pdam', 'rame', 'pdam jalan gresik mati', 'tugas wilayah ploso timur kali cek preman ketuk pagar ugal-ugalan kayu pentung preman pagar tetangga', 'kali kirim komplain langsung pecat tugas', 'pdam hati alir baik', 'kebraon susah aktivitas', 'laku', 'syarat lengkap proses pasang', 'karah mati ada pemberitahuan tayamum', 'aju tanggal september keluar rincian tanggal september bayar batas bayar smp oktober harga promo agustus smp september ada promo', 'dm', 'rungkut industri mati', 'pdam keruh', 'kertaja kecil tidak', 'karang menjangan susah bos', 'tagih pdam lonjak drastis', 'pdam wonorejo rungkut mati', 'adu gubris cs tugas mati hari meter bocor habis ganti meter masalah', 'informasi ganggu wilayah babat jerawat pondok benowo indah', 'baik nyala rutinitas pdam pekan nyala', 'jalan juwingan mati ada informasi mohon informasi mati', 'informasi tanggal promo', 'karah mati', 'ruwet bayar pasang bulan', 'daftar pasang pdam daftar', 'pdam normal minggu pagi nyala wonorejo manuk kulon', 'lidah kulon mati hari', 'ada baik mati malam', 'pdam baik keruh bau kayak bagus aju komplain cek bersih isi pagi bau keruh pdam adu tugas bosan rumah', 'kebraon mati', 'kebraon mati', 'mati pdam kebraon ad pemberitahuan', 'karah mati ada ap efek gorong-gorong bikin sedih masak minggu ganti wifi mati', 'aju tanggal september ada pasang ada pasang', 'tugas kumpul berkas info minggu pasang', 'kebraon mati', 'pagi daerah karah mati tidak ada pemberitahuan ada', 'mati', 'mati wisma pagesangan tidak ada pemberitahuan mati', 'simo tambaan barusan mertua tugas abal suruh ganti meter', 'meter ganti', 'tidak ada tugas cek meter salah langgan', 'mohon bantu pdam wilayah kebraon tidak alir tanggal malam pagi tidak ada kompensasi tangki', 'berangkat sekolah berangkat kerja pdam mati daerah pondok maritim lurah balas klumprik', 'daerah gading karya pagi mati sore mati', 'ulan', 'sore malam mati daerah komplek tni al juanda susah', 'keluar', 'komplek tni al juanda sore tidak ada sekolah kantor', 'kebraon mati tidak ada informasi sm tugas', 'pagi pdam kebraon gang sekolah mati baik gang tomat kebraon pagi mati debit kecil mohon ada baik wilayah pokok tekan kurang pagi mati', 'tidak keluar mati tandon tip', 'pdam daerah jiwa mati', 'hubung telepon wib siang tidak ada tugas', 'senin tanggal oktober tugas pdam ganti meter ganti meter gerak kran tutup lokasi kedung baruk rungkut', 'ada tugas baik pipa bocor lokasi', 'pagi pdam pdam gayung kebonsari pagi tidak keluar alir siang mohon informasi bantu', 'kerja', 'jadwal catat mandiri tanggal ubah pikir pergi kota', 'telepon no sibuk', 'terang proses cepat kumpul berkas tanggal september ada pasang', 'kirim pesan', 'daftar daring via aplikasi tahap verifikasi pasang butuh', 'nomor antri mohon bantu', 'daerah jalan gresik mati pdam mohon tindak ada', 'pdam mati wilayah rumah pondok maritim ada pemberitahuan tidur mati anak kerja sekolah butuh mandi', 'pagi mati area wisma lidah kulon', 'nyala', 'nyala', 'admin area dupak keluar chat tangki ada respon', 'telepon call center respon adu rusa meter', 'ada', 'proyek', 'anjir', 'pdam jalan raya sambikerep mati', 'ada pemberitahuan antisipasi lupa tidak ada pemberitahuan', 'informasi', 'keren instalasi ipam ngagel', 'keren olah ipam ngagel', 'dang ipam ngagel keren', 'baik', 'perumda minum populer', 'maju layan', 'keren', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'lahir to be bangga besar as indonesia', 'alir semangat muda', 'sumpah pemuda', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'sumpah pemuda cermin berani anak bangsa satu tengah beda', 'rumah daerah ptc surabaya barat keruh kemaren', 'bagus', 'jambang mati sabtu siang nyala bayar', 'jambang nyala cm', 'medayu mati ada baik', 'sambikerep mati gada pemberitahuan', 'mati pagi mandi tayamum sambikerep', 'keluar nang sambikerep berangkat kerja mandi keluar', 'medok ayu mati', 'area medayu mati', 'nyala ada pemberitahuan status pdam ada pemberitahuan', 'bantu pipa s ...
#   Keywords: mati(0.332)
#
# Cluster 3  (1 members)
#   Members: ['admin bicara baik nyata nang keluar bablas tetes kran buka pagi berangkat kerja pulang kerja bak ku kosong']
#   Keywords: admin(1.000), bablas(1.000), baik(1.000), bak(1.000), berangkat(1.000), bicara(1.000), buka(1.000), keluar(1.000), kerja(1.000), kosong(1.000)
#
# Cluster 4  (1 members)
#   Members: ['pdam hormat mohon baik debit kali mati baik tidak keluar keluar bu bayang posisi tidak tandon ganggu aktivasi rumah tangga hari']
#   Keywords: aktivasi(1.000), baik(1.000), bayang(1.000), bu(1.000), debit(1.000), ganggu(1.000), hari(1.000), hormat(1.000), kali(1.000), keluar(1.000)
#
# Cluster 5  (1 members)
#   Members: ['jawab balas templat mohon baik bantu tangki gratis bantu tandon bantu simpan isi bak kamar mandi solusi pikir cari solusi']
#   Keywords: baik(1.000), bak(1.000), balas(1.000), bantu(1.000), cari(1.000), gratis(1.000), isi(1.000), jawab(1.000), kamar(1.000), mandi(1.000)
#
# Cluster 6  (1 members)
#   Members: ['rumah griya surabaya asri gorong-gorong mati ape umbah umbah seragam pasang pikir ada pompa butek mati awak bayar duduk subsidi']
#   Keywords: ada(1.000), ape(1.000), asri(1.000), awak(1.000), bayar(1.000), butek(1.000), duduk(1.000), gorong-gorong(1.000), griya(1.000), mati(1.000)
#
# Cluster 7  (1 members)
#   Members: ['rumah daerah muhammad mari bocor mari baik admin pagi awan malam mantap pagi nyala kran dapur tunggu awan admin nak dapur pompa admin tanda bocor admin']
#   Keywords: admin(1.000), awan(1.000), baik(1.000), bocor(1.000), daerah(1.000), dapur(1.000), kran(1.000), malam(1.000), mantap(1.000), mari(1.000)
#
# Cluster 8  (1 members)
#   Members: ['daerah jalan kaum gang masak sabtu minggu mati keluar lapor call center ada tugas periksa tidak minggu pagi mohon perhati']
#   Keywords: ada(1.000), call(1.000), center(1.000), daerah(1.000), gang(1.000), jalan(1.000), kaum(1.000), keluar(1.000), lapor(1.000), masak(1.000)
#
# Cluster 9  (1 members)
#   Members: ['bu kayak gorong-gorong kerja area tanggal beres perhati ada proyek gali mesti bocor kayak paham situbada karingan pipa jarak']
#   Keywords: ada(1.000), area(1.000), beres(1.000), bocor(1.000), bu(1.000), gali(1.000), gorong-gorong(1.000), jarak(1.000), karingan(1.000), kayak(1.000)
#
# Cluster 10  (1 members)
#   Members: ['anak buang beli galon ada ge tandon cebok ge shalat butuh wudhu ra tau mandi awak lengket mok tayamum']
#   Keywords: ada(1.000), anak(1.000), awak(1.000), beli(1.000), buang(1.000), butuh(1.000), cebok(1.000), galon(1.000), ge(1.000), lengket(1.000)
#
# Cluster 11  (1 members)
#   Members: ['admin telepon call center sibuk pdam surabaya panas nyala daerah tambak mayor barat telat bayat denda atur komplain respon']
#   Keywords: admin(1.000), atur(1.000), barat(1.000), bayat(1.000), call(1.000), center(1.000), daerah(1.000), denda(1.000), komplain(1.000), mayor(1.000)
#
# Cluster 12  (1 members)
#   Members: ['malam admin daerah mleto surabaya timur sukolilo september habis subuh siang mati tidak keluar lancar siang sore malam mati mati pagi repot pagi berangkat kerja']
#   Keywords: admin(1.000), berangkat(1.000), daerah(1.000), habis(1.000), keluar(1.000), kerja(1.000), lancar(1.000), malam(1.000), mati(1.000), mleto(1.000)
#
# Cluster 13  (1 members)
#   Members: ['urus kampung rt bantu warga alami stop kran posisi buka tidak keluar sangkut aju keluh adu via wa pdam']
#   Keywords: adu(1.000), aju(1.000), alami(1.000), bantu(1.000), buka(1.000), kampung(1.000), keluar(1.000), keluh(1.000), kran(1.000), pdam(1.000)
#
# Cluster 14  (1 members)
#   Members: ['barusan rumah aku tugas pdam tuju ganti meter pdam surat tugas beliau tidak foto orang kendara tidak surat tugas langsung pergi alas rumit bongkar']
#   Keywords: aku(1.000), alas(1.000), barusan(1.000), beliau(1.000), bongkar(1.000), foto(1.000), ganti(1.000), kendara(1.000), langsung(1.000), meter(1.000)
#
# Cluster 15  (1 members)
#   Members: ['wilayah bronggalan keluar da pagi sd malam sd tahun mohon solusi lapor tugas alir cek pdam surabaya perhati daerah lancar ada']
#   Keywords: ada(1.000), alir(1.000), bronggalan(1.000), cek(1.000), da(1.000), daerah(1.000), keluar(1.000), lancar(1.000), lapor(1.000), malam(1.000)
#
# Cluster 16  (1 members)
#   Members: ['ak telepon jawab lapor kait kerja telepon jawab templat warga pbi keluar malam khusus pakai pompa keluar tetea keluar bulan malam subuh nyala kemaren malam detik keluar']
#   Keywords: ak(1.000), bulan(1.000), detik(1.000), jawab(1.000), kait(1.000), keluar(1.000), kemaren(1.000), kerja(1.000), khusus(1.000), lapor(1.000)
#
# Cluster 17  (1 members)
#   Members: ['tidak keluar mati pagi subuh tu liat ada kerja bego gali situ gali area situ tutup gali tutup ada bocor mohon cek ada informasi pdam mati kejar produksi sulit']
#   Keywords: ada(1.000), area(1.000), bego(1.000), bocor(1.000), cek(1.000), gali(1.000), informasi(1.000), kejar(1.000), keluar(1.000), kerja(1.000)
#
# Cluster 18  (1 members)
#   Members: ['lapor pdam gara-gara jumat malam nyala ak paksa tidur hawa panas badan lengket nyala langsung mandi isi bak cuci subuh ape tidur bos']
#   Keywords: ak(1.000), ape(1.000), badan(1.000), bak(1.000), bos(1.000), cuci(1.000), gara-gara(1.000), hawa(1.000), isi(1.000), jumat(1.000)
#
# Cluster 19  (1 members)
#   Members: ['minggu tunggu keluar malam keluar tidur tunggu gilir bayar telat denda bantu keluar kerja pompa lelah listrik listrik subsidi listrik mandiri alias bayar keluar ky got hitam letek']
#   Keywords: alias(1.000), bantu(1.000), bayar(1.000), denda(1.000), gilir(1.000), got(1.000), hitam(1.000), keluar(1.000), kerja(1.000), ky(1.000)
#
# Cluster 20  (1 members)
#   Members: ['pdam hebat kl ada lambat bayar cepat putus alir langgan bikin langgan bingung dg alir ada pemberitahuan nomor warga taman telaga bodas karangrejo gajahmungkur semarang']
#   Keywords: ada(1.000), alir(1.000), bayar(1.000), bikin(1.000), bingung(1.000), bodas(1.000), cepat(1.000), dg(1.000), gajahmungkur(1.000), hebat(1.000)
#
# Cluster 21  (1 members)
#   Members: ['japri lapang langsung capek kotak culvert mohon bantu ikut cepet diare puyeng mati omset umkm dampak langgan rugi bayar tagih pdam dpt maksimal']
#   Keywords: bantu(1.000), bayar(1.000), capek(1.000), cepet(1.000), culvert(1.000), dampak(1.000), diare(1.000), dpt(1.000), ikut(1.000), japri(1.000)
#
# Cluster 22  (1 members)
#   Members: ['keluar humas ada baik sosialisasi sosial media ikut pdam sosialisasi dampak ksi solusi water tank komen sm tetangga jalan angkut orang tua mohon bijak']
#   Keywords: ada(1.000), angkut(1.000), baik(1.000), bijak(1.000), dampak(1.000), humas(1.000), ikut(1.000), jalan(1.000), keluar(1.000), komen(1.000)
#
# Cluster 23  (1 members)
#   Members: ['proyek pemkot area bocor bego seberang alfamart kerja pegawai beda area sat set hati jarang ada bocor pipa titik mohon warga rugi tutup usaha omset parah']
#   Keywords: ada(1.000), alfamart(1.000), area(1.000), beda(1.000), bego(1.000), bocor(1.000), hati(1.000), jarang(1.000), kerja(1.000), mohon(1.000)
#
# Cluster 24  (1 members)
#   Members: ['dasar cari google kunci daerah bekas tambang minyak surabaya zaman belanda gunung anyar salah daerah daerah kutisari ada sembur kali lidi instansi kait moga investigasi laku']
#   Keywords: ada(1.000), anyar(1.000), bekas(1.000), belanda(1.000), cari(1.000), daerah(1.000), dasar(1.000), google(1.000), gunung(1.000), instansi(1.000)
#
# Cluster 25  (1 members)
#   Members: ['cari solusi ulang ada pipa bocor pdam alangkah cari solusi bocor bocor baik cepat hambat aktivitas warga butuh pdam warga bayar bantu gratis tagih tidak murah bocor pipa cari solusi perintah tag ada peduli perintah ulang bagus ulang ada ubah baik']
#   Keywords: ada(1.000), aktivitas(1.000), alangkah(1.000), bagus(1.000), baik(1.000), bantu(1.000), bayar(1.000), bocor(1.000), butuh(1.000), cari(1.000)
#
# Cluster 26  (1 members)
#   Members: ['usaha cepat kira tuntut pbi ku habis sengaja tidak isi perak pbi bening abis baik nyala butek super butek tuju ku habis tandon minggu pbi nyala bening minggu ada baik baik nyala bersih jernih baik nyala keruh kecil debit usaha kira']
#   Keywords: abis(1.000), ada(1.000), baik(1.000), bening(1.000), bersih(1.000), butek(1.000), cepat(1.000), debit(1.000), habis(1.000), isi(1.000)
#
# Cluster 27  (1 members)
#   Members: ['merek pipa kualitas seng pakai bocor mati bayar mahal bolak mati minggu mati cuci seragam yak cak elus karo pikir tangki solusi pikir kudu kolektif rt pesan tangki wadah seng tandon coba pikir solusi']
#   Keywords: bayar(1.000), bocor(1.000), bolak(1.000), cak(1.000), coba(1.000), cuci(1.000), elus(1.000), karo(1.000), kolektif(1.000), kualitas(1.000)
#
# Cluster 28  (1 members)
#   Members: ['pantau gorong-gorong daerah sumber laku ubah mati baik jaring informasi orang anggur pagi ate sambut kerja mati fungsi orang ikut akun erti informasi klarifikasi bukti slogan gerak cepat seng cepat seng informasi dadi klarifikasi bodoh']
#   Keywords: akun(1.000), anggur(1.000), ate(1.000), baik(1.000), bodoh(1.000), bukti(1.000), cepat(1.000), dadi(1.000), daerah(1.000), erti(1.000)
#
# Cluster 29  (1 members)
#   Members: ['pekan pdam kunjung rumah istri tangan no surat tidak ada apa informasi janji to ganti meter has to be jadwal meter not until pekan no informasi layan mohon cek maksud jalan has tidak ada apa to do layan do butuh informasi mohon via messenger']
#   Keywords: ada(1.000), apa(1.000), be(1.000), butuh(1.000), cek(1.000), do(1.000), ganti(1.000), has(1.000), informasi(1.000), istri(1.000)
#
# Cluster 30  (1 members)
#   Members: ['malam informasi alir rumah mati akibat pipa pdam buntu dampak kerja kotak culvert mulyosari lapor rabu malam jumat ada respon tugas pdam baik janji janji ada tugas hubung contoh pln depan langgan layan janji janji tidak baik jalan bhaskara no janji']
#   Keywords: ada(1.000), akibat(1.000), alir(1.000), baik(1.000), bhaskara(1.000), buntu(1.000), contoh(1.000), culvert(1.000), dampak(1.000), depan(1.000)
#
# Cluster 31  (1 members)
#   Members: ['warga tinggal dinding tengah xi alami tidak senang pdam keluar butuh tidak keluar siang keluar malam contoh pagi minggu oktober cuci pakai keluar normal tengah giat cuci tidak alir pdam rumah sedot pompa tetangga rutin adu tugas tangan ada ubah bayar bulan rutin layan kecewa']
#   Keywords: ada(1.000), adu(1.000), alami(1.000), alir(1.000), bayar(1.000), bulan(1.000), butuh(1.000), contoh(1.000), cuci(1.000), dinding(1.000)
#
# Cluster 32  (1 members)
#   Members: ['informasi mepet malam tidur bangun bangun petang nyala kamar mandi keluar langsung pikir cek instagram pdam ada baik tagih ribu total juta ribu kondisi tidak nyala mati baik ulang mati rumah tandon sumur andal pdam sulit baik kali nama rugi bocor pipa tagih murah oke oke pakai tagih padan']
#   Keywords: ada(1.000), andal(1.000), baik(1.000), bangun(1.000), bocor(1.000), cek(1.000), informasi(1.000), instagram(1.000), juta(1.000), kali(1.000)
#
# ------------------------------
# Cluster Details — [CENTROID] Scenario 4 (Threshold + Binary)  (k=26)
#
# Cluster 1  (2 members)
#   Members: ['lapor warga gayungsari barat keluh pdam mati ada pipa rusak akibat gali kotak culvert empat lintas lampu gayungsari barat', 'kontraktor gali kotak culvert ada pipa rusak empat lintas lampu jalan gayungsari barat mohon bantu warga keluh']
#   Keywords: ada(1.000), barat(1.000), culvert(1.000), empat(1.000), gali(1.000), gayungsari(1.000), keluh(1.000), kotak(1.000), lampu(1.000), lintas(1.000)
#
# Cluster 2  (1102 members)
#   Members: ['paham harga pasang pdam', 'rame', 'pdam jalan gresik mati', 'tugas wilayah ploso timur kali cek preman ketuk pagar ugal-ugalan kayu pentung preman pagar tetangga', 'kali kirim komplain langsung pecat tugas', 'pdam hati alir baik', 'kebraon susah aktivitas', 'laku', 'syarat lengkap proses pasang', 'karah mati ada pemberitahuan tayamum', 'aju tanggal september keluar rincian tanggal september bayar batas bayar smp oktober harga promo agustus smp september ada promo', 'dm', 'rungkut industri mati', 'pdam keruh', 'kertaja kecil tidak', 'karang menjangan susah bos', 'tagih pdam lonjak drastis', 'pdam wonorejo rungkut mati', 'adu gubris cs tugas mati hari meter bocor habis ganti meter masalah', 'informasi ganggu wilayah babat jerawat pondok benowo indah', 'baik nyala rutinitas pdam pekan nyala', 'jalan juwingan mati ada informasi mohon informasi mati', 'informasi tanggal promo', 'karah mati', 'ruwet bayar pasang bulan', 'daftar pasang pdam daftar', 'pdam normal minggu pagi nyala wonorejo manuk kulon', 'lidah kulon mati hari', 'ada baik mati malam', 'kebraon mati', 'kebraon mati', 'mati pdam kebraon ad pemberitahuan', 'karah mati ada ap efek gorong-gorong bikin sedih masak minggu ganti wifi mati', 'aju tanggal september ada pasang ada pasang', 'tugas kumpul berkas info minggu pasang', 'kebraon mati', 'pagi daerah karah mati tidak ada pemberitahuan ada', 'mati', 'mati wisma pagesangan tidak ada pemberitahuan mati', 'barusan rumah aku tugas pdam tuju ganti meter pdam surat tugas beliau tidak foto orang kendara tidak surat tugas langsung pergi alas rumit bongkar', 'simo tambaan barusan mertua tugas abal suruh ganti meter', 'meter ganti', 'tidak ada tugas cek meter salah langgan', 'mohon bantu pdam wilayah kebraon tidak alir tanggal malam pagi tidak ada kompensasi tangki', 'berangkat sekolah berangkat kerja pdam mati daerah pondok maritim lurah balas klumprik', 'daerah gading karya pagi mati sore mati', 'ulan', 'sore malam mati daerah komplek tni al juanda susah', 'keluar', 'komplek tni al juanda sore tidak ada sekolah kantor', 'kebraon mati tidak ada informasi sm tugas', 'pagi pdam kebraon gang sekolah mati baik gang tomat kebraon pagi mati debit kecil mohon ada baik wilayah pokok tekan kurang pagi mati', 'tidak keluar mati tandon tip', 'pdam daerah jiwa mati', 'hubung telepon wib siang tidak ada tugas', 'senin tanggal oktober tugas pdam ganti meter ganti meter gerak kran tutup lokasi kedung baruk rungkut', 'ada tugas baik pipa bocor lokasi', 'pagi pdam pdam gayung kebonsari pagi tidak keluar alir siang mohon informasi bantu', 'kerja', 'jadwal catat mandiri tanggal ubah pikir pergi kota', 'telepon no sibuk', 'terang proses cepat kumpul berkas tanggal september ada pasang', 'kirim pesan', 'daftar daring via aplikasi tahap verifikasi pasang butuh', 'pekan pdam kunjung rumah istri tangan no surat tidak ada apa informasi janji to ganti meter has to be jadwal meter not until pekan no informasi layan mohon cek maksud jalan has tidak ada apa to do layan do butuh informasi mohon via messenger', 'nomor antri mohon bantu', 'daerah jalan gresik mati pdam mohon tindak ada', 'pdam mati wilayah rumah pondok maritim ada pemberitahuan tidur mati anak kerja sekolah butuh mandi', 'pagi mati area wisma lidah kulon', 'nyala', 'nyala', 'admin area dupak keluar chat tangki ada respon', 'telepon call center respon adu rusa meter', 'ada', 'proyek', 'anjir', 'pdam jalan raya sambikerep mati', 'ada pemberitahuan antisipasi lupa tidak ada pemberitahuan', 'informasi', 'keren instalasi ipam ngagel', 'keren olah ipam ngagel', 'dang ipam ngagel keren', 'baik', 'perumda minum populer', 'maju layan', 'keren', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'lahir to be bangga besar as indonesia', 'alir semangat muda', 'sumpah pemuda', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'sumpah pemuda cermin berani anak bangsa satu tengah beda', 'rumah daerah ptc surabaya barat keruh kemaren', 'bagus', 'jambang mati sabtu siang nyala b ...
#   Keywords: mati(0.328)
#
# Cluster 3  (1 members)
#   Members: ['paham kesal pagi telepon call center bilang informasi tanggal tanggal jawab rajin cek instagram pdam ada informasi']
#   Keywords: ada(1.000), bilang(1.000), call(1.000), cek(1.000), center(1.000), informasi(1.000), instagram(1.000), jawab(1.000), kesal(1.000), pagi(1.000)
#
# Cluster 4  (1 members)
#   Members: ['dar motto pdam surabaya layan minggu ada ganggu lokasi jarak dekat tidak kerja sama tidak ganggu langgan']
#   Keywords: ada(1.000), dar(1.000), dekat(1.000), ganggu(1.000), jarak(1.000), kerja(1.000), langgan(1.000), layan(1.000), lokasi(1.000), minggu(1.000)
#
# Cluster 5  (1 members)
#   Members: ['telepon pdam jawab telepon pakai rumah kendala komplek instagram rame lapor pura tidak parah hari nyala']
#   Keywords: hari(1.000), instagram(1.000), jawab(1.000), kendala(1.000), komplek(1.000), lapor(1.000), nyala(1.000), pakai(1.000), parah(1.000), pdam(1.000)
#
# Cluster 6  (1 members)
#   Members: ['anak diare sengsara parah mota mati hari malam nyala paksa malam cuci mandi keramas untung surabaya panas']
#   Keywords: anak(1.000), cuci(1.000), diare(1.000), hari(1.000), keramas(1.000), malam(1.000), mandi(1.000), mati(1.000), mota(1.000), nyala(1.000)
#
# Cluster 7  (1 members)
#   Members: ['harga kerja lapang hari alir lancar mampet daerah gayung ada kali pagi ada informasi baru ganggu aktivitas']
#   Keywords: ada(1.000), aktivitas(1.000), alir(1.000), baru(1.000), daerah(1.000), ganggu(1.000), gayung(1.000), harga(1.000), hari(1.000), informasi(1.000)
#
# Cluster 8  (1 members)
#   Members: ['lihat ulan tanggal september oktober bolak balek mbok mati alir debit cilik mari alas mati sebal benar']
#   Keywords: alas(1.000), alir(1.000), balek(1.000), benar(1.000), bolak(1.000), cilik(1.000), debit(1.000), lihat(1.000), mari(1.000), mati(1.000)
#
# Cluster 9  (1 members)
#   Members: ['pdam baik keruh bau kayak bagus aju komplain cek bersih isi pagi bau keruh pdam adu tugas bosan rumah']
#   Keywords: adu(1.000), aju(1.000), bagus(1.000), baik(1.000), bau(1.000), bersih(1.000), bosan(1.000), cek(1.000), isi(1.000), kayak(1.000)
#
# Cluster 10  (1 members)
#   Members: ['bicara gampang tampung tampung hujan musim kemarau kirim pasok kudu warga gampang pdam oh pdam tarif denda telat no']
#   Keywords: bicara(1.000), denda(1.000), gampang(1.000), hujan(1.000), kemarau(1.000), kirim(1.000), kudu(1.000), musim(1.000), no(1.000), oh(1.000)
#
# Cluster 11  (1 members)
#   Members: ['benar pondok benowo indah hari pdam keluar coba cek baik sememi pagi coba nyala keluar mandi sakit sembuh krisis pondok benowo indah']
#   Keywords: baik(1.000), benar(1.000), benowo(1.000), cek(1.000), coba(1.000), hari(1.000), indah(1.000), keluar(1.000), krisis(1.000), mandi(1.000)
#
# Cluster 12  (1 members)
#   Members: ['walah minggu kampung lancar rumah pinggir jalan mati minggu angsu gempor tangan angkat galon suk bayar zalim jeneng']
#   Keywords: angkat(1.000), angsu(1.000), bayar(1.000), galon(1.000), gempor(1.000), jalan(1.000), jeneng(1.000), kampung(1.000), lancar(1.000), mati(1.000)
#
# Cluster 13  (1 members)
#   Members: ['admin bicara baik nyata nang keluar bablas tetes kran buka pagi berangkat kerja pulang kerja bak ku kosong']
#   Keywords: admin(1.000), bablas(1.000), baik(1.000), bak(1.000), berangkat(1.000), bicara(1.000), buka(1.000), keluar(1.000), kerja(1.000), kosong(1.000)
#
# Cluster 14  (1 members)
#   Members: ['pdam hormat mohon baik debit kali mati baik tidak keluar keluar bu bayang posisi tidak tandon ganggu aktivasi rumah tangga hari']
#   Keywords: aktivasi(1.000), baik(1.000), bayang(1.000), bu(1.000), debit(1.000), ganggu(1.000), hari(1.000), hormat(1.000), kali(1.000), keluar(1.000)
#
# Cluster 15  (1 members)
#   Members: ['rumah griya surabaya asri gorong-gorong mati ape umbah umbah seragam pasang pikir ada pompa butek mati awak bayar duduk subsidi']
#   Keywords: ada(1.000), ape(1.000), asri(1.000), awak(1.000), bayar(1.000), butek(1.000), duduk(1.000), gorong-gorong(1.000), griya(1.000), mati(1.000)
#
# Cluster 16  (1 members)
#   Members: ['daerah jalan kaum gang masak sabtu minggu mati keluar lapor call center ada tugas periksa tidak minggu pagi mohon perhati']
#   Keywords: ada(1.000), call(1.000), center(1.000), daerah(1.000), gang(1.000), jalan(1.000), kaum(1.000), keluar(1.000), lapor(1.000), masak(1.000)
#
# Cluster 17  (1 members)
# ...
#   Keywords: informasi(3.000), to(3.000), do(2.000), ada(2.000), has(2.000), layan(2.000), meter(2.000), apa(2.000), mohon(2.000), no(2.000)
#
# Cluster 8  (1 members)
#   Members: ['usaha cepat kira tuntut pbi ku habis sengaja tidak isi perak pbi bening abis baik nyala butek super butek tuju ku habis tandon minggu pbi nyala bening minggu ada baik baik nyala bersih jernih baik nyala keruh kecil debit usaha kira']
#   Keywords: baik(4.000), nyala(4.000), pbi(3.000)
#
# Cluster 9  (1 members)
#   Members: ['cari solusi ulang ada pipa bocor pdam alangkah cari solusi bocor bocor baik cepat hambat aktivitas warga butuh pdam warga bayar bantu gratis tagih tidak murah bocor pipa cari solusi perintah tag ada peduli perintah ulang bagus ulang ada ubah baik']
#   Keywords: bocor(4.000), ada(3.000), cari(3.000), solusi(3.000), ulang(3.000)
#
# ------------------------------
# Cluster Details — [AVERAGE] Scenario 3 (Binary)  (k=5)
#
# Cluster 1  (1124 members)
#   Members: ['paham harga pasang pdam', 'rame', 'pdam jalan gresik mati', 'tugas wilayah ploso timur kali cek preman ketuk pagar ugal-ugalan kayu pentung preman pagar tetangga', 'kali kirim komplain langsung pecat tugas', 'pdam hati alir baik', 'kebraon susah aktivitas', 'laku', 'syarat lengkap proses pasang', 'karah mati ada pemberitahuan tayamum', 'aju tanggal september keluar rincian tanggal september bayar batas bayar smp oktober harga promo agustus smp september ada promo', 'dm', 'rungkut industri mati', 'pdam keruh', 'kertaja kecil tidak', 'karang menjangan susah bos', 'tagih pdam lonjak drastis', 'pdam wonorejo rungkut mati', 'adu gubris cs tugas mati hari meter bocor habis ganti meter masalah', 'informasi ganggu wilayah babat jerawat pondok benowo indah', 'lapor pdam gara-gara jumat malam nyala ak paksa tidur hawa panas badan lengket nyala langsung mandi isi bak cuci subuh ape tidur bos', 'baik nyala rutinitas pdam pekan nyala', 'jalan juwingan mati ada informasi mohon informasi mati', 'informasi tanggal promo', 'karah mati', 'ruwet bayar pasang bulan', 'daftar pasang pdam daftar', 'pdam normal minggu pagi nyala wonorejo manuk kulon', 'lidah kulon mati hari', 'ada baik mati malam', 'pdam baik keruh bau kayak bagus aju komplain cek bersih isi pagi bau keruh pdam adu tugas bosan rumah', 'kebraon mati', 'kebraon mati', 'mati pdam kebraon ad pemberitahuan', 'karah mati ada ap efek gorong-gorong bikin sedih masak minggu ganti wifi mati', 'aju tanggal september ada pasang ada pasang', 'tugas kumpul berkas info minggu pasang', 'kebraon mati', 'pagi daerah karah mati tidak ada pemberitahuan ada', 'mati', 'mati wisma pagesangan tidak ada pemberitahuan mati', 'barusan rumah aku tugas pdam tuju ganti meter pdam surat tugas beliau tidak foto orang kendara tidak surat tugas langsung pergi alas rumit bongkar', 'simo tambaan barusan mertua tugas abal suruh ganti meter', 'meter ganti', 'tidak ada tugas cek meter salah langgan', 'mohon bantu pdam wilayah kebraon tidak alir tanggal malam pagi tidak ada kompensasi tangki', 'berangkat sekolah berangkat kerja pdam mati daerah pondok maritim lurah balas klumprik', 'daerah gading karya pagi mati sore mati', 'ulan', 'sore malam mati daerah komplek tni al juanda susah', 'keluar', 'komplek tni al juanda sore tidak ada sekolah kantor', 'kebraon mati tidak ada informasi sm tugas', 'pagi pdam kebraon gang sekolah mati baik gang tomat kebraon pagi mati debit kecil mohon ada baik wilayah pokok tekan kurang pagi mati', 'tidak keluar mati tandon tip', 'pdam daerah jiwa mati', 'hubung telepon wib siang tidak ada tugas', 'senin tanggal oktober tugas pdam ganti meter ganti meter gerak kran tutup lokasi kedung baruk rungkut', 'ada tugas baik pipa bocor lokasi', 'pagi pdam pdam gayung kebonsari pagi tidak keluar alir siang mohon informasi bantu', 'kerja', 'jadwal catat mandiri tanggal ubah pikir pergi kota', 'telepon no sibuk', 'terang proses cepat kumpul berkas tanggal september ada pasang', 'kirim pesan', 'daftar daring via aplikasi tahap verifikasi pasang butuh', 'nomor antri mohon bantu', 'daerah jalan gresik mati pdam mohon tindak ada', 'pdam mati wilayah rumah pondok maritim ada pemberitahuan tidur mati anak kerja sekolah butuh mandi', 'pagi mati area wisma lidah kulon', 'nyala', 'nyala', 'admin area dupak keluar chat tangki ada respon', 'telepon call center respon adu rusa meter', 'ada', 'proyek', 'anjir', 'pdam jalan raya sambikerep mati', 'ada pemberitahuan antisipasi lupa tidak ada pemberitahuan', 'informasi', 'keren instalasi ipam ngagel', 'keren olah ipam ngagel', 'dang ipam ngagel keren', 'baik', 'perumda minum populer', 'maju layan', 'keren', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'lahir to be bangga besar as indonesia', 'alir semangat muda', 'sumpah pemuda', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'sumpah pemuda cermin berani anak bangsa satu tengah beda', 'rumah daerah ptc surabaya barat keruh kemaren', 'bagus', 'jambang mati sabtu siang nyala bayar ...
#   Keywords: mati(0.333)
#
# Cluster 2  (1 members)
#   Members: ['pekan pdam kunjung rumah istri tangan no surat tidak ada apa informasi janji to ganti meter has to be jadwal meter not until pekan no informasi layan mohon cek maksud jalan has tidak ada apa to do layan do butuh informasi mohon via messenger']
#   Keywords: ada(1.000), apa(1.000), be(1.000), butuh(1.000), cek(1.000), do(1.000), ganti(1.000), has(1.000), informasi(1.000), istri(1.000)
#
# Cluster 3  (1 members)
#   Members: ['malam informasi alir rumah mati akibat pipa pdam buntu dampak kerja kotak culvert mulyosari lapor rabu malam jumat ada respon tugas pdam baik janji janji ada tugas hubung contoh pln depan langgan layan janji janji tidak baik jalan bhaskara no janji']
#   Keywords: ada(1.000), akibat(1.000), alir(1.000), baik(1.000), bhaskara(1.000), buntu(1.000), contoh(1.000), culvert(1.000), dampak(1.000), depan(1.000)
#
# Cluster 4  (1 members)
#   Members: ['warga tinggal dinding tengah xi alami tidak senang pdam keluar butuh tidak keluar siang keluar malam contoh pagi minggu oktober cuci pakai keluar normal tengah giat cuci tidak alir pdam rumah sedot pompa tetangga rutin adu tugas tangan ada ubah bayar bulan rutin layan kecewa']
#   Keywords: ada(1.000), adu(1.000), alami(1.000), alir(1.000), bayar(1.000), bulan(1.000), butuh(1.000), contoh(1.000), cuci(1.000), dinding(1.000)
#
# Cluster 5  (1 members)
#   Members: ['informasi mepet malam tidur bangun bangun petang nyala kamar mandi keluar langsung pikir cek instagram pdam ada baik tagih ribu total juta ribu kondisi tidak nyala mati baik ulang mati rumah tandon sumur andal pdam sulit baik kali nama rugi bocor pipa tagih murah oke oke pakai tagih padan']
#   Keywords: ada(1.000), andal(1.000), baik(1.000), bangun(1.000), bocor(1.000), cek(1.000), informasi(1.000), instagram(1.000), juta(1.000), kali(1.000)
#
# ------------------------------
# Cluster Details — [AVERAGE] Scenario 4 (Threshold + Binary)  (k=16)
#
# Cluster 1  (2 members)
#   Members: ['lapor warga gayungsari barat keluh pdam mati ada pipa rusak akibat gali kotak culvert empat lintas lampu gayungsari barat', 'kontraktor gali kotak culvert ada pipa rusak empat lintas lampu jalan gayungsari barat mohon bantu warga keluh']
#   Keywords: ada(1.000), barat(1.000), culvert(1.000), empat(1.000), gali(1.000), gayungsari(1.000), keluh(1.000), kotak(1.000), lampu(1.000), lintas(1.000)
#
# Cluster 2  (1112 members)
#   Members: ['paham harga pasang pdam', 'rame', 'pdam jalan gresik mati', 'tugas wilayah ploso timur kali cek preman ketuk pagar ugal-ugalan kayu pentung preman pagar tetangga', 'kali kirim komplain langsung pecat tugas', 'pdam hati alir baik', 'kebraon susah aktivitas', 'laku', 'syarat lengkap proses pasang', 'karah mati ada pemberitahuan tayamum', 'aju tanggal september keluar rincian tanggal september bayar batas bayar smp oktober harga promo agustus smp september ada promo', 'dm', 'rungkut industri mati', 'pdam keruh', 'kertaja kecil tidak', 'karang menjangan susah bos', 'tagih pdam lonjak drastis', 'pdam wonorejo rungkut mati', 'adu gubris cs tugas mati hari meter bocor habis ganti meter masalah', 'informasi ganggu wilayah babat jerawat pondok benowo indah', 'baik nyala rutinitas pdam pekan nyala', 'jalan juwingan mati ada informasi mohon informasi mati', 'informasi tanggal promo', 'karah mati', 'ruwet bayar pasang bulan', 'daftar pasang pdam daftar', 'pdam normal minggu pagi nyala wonorejo manuk kulon', 'lidah kulon mati hari', 'ada baik mati malam', 'pdam baik keruh bau kayak bagus aju komplain cek bersih isi pagi bau keruh pdam adu tugas bosan rumah', 'kebraon mati', 'kebraon mati', 'mati pdam kebraon ad pemberitahuan', 'karah mati ada ap efek gorong-gorong bikin sedih masak minggu ganti wifi mati', 'aju tanggal september ada pasang ada pasang', 'tugas kumpul berkas info minggu pasang', 'kebraon mati', 'pagi daerah karah mati tidak ada pemberitahuan ada', 'mati', 'mati wisma pagesangan tidak ada pemberitahuan mati', 'barusan rumah aku tugas pdam tuju ganti meter pdam surat tugas beliau tidak foto orang kendara tidak surat tugas langsung pergi alas rumit bongkar', 'simo tambaan barusan mertua tugas abal suruh ganti meter', 'meter ganti', 'tidak ada tugas cek meter salah langgan', 'mohon bantu pdam wilayah kebraon tidak alir tanggal malam pagi tidak ada kompensasi tangki', 'berangkat sekolah berangkat kerja pdam mati daerah pondok maritim lurah balas klumprik', 'daerah gading karya pagi mati sore mati', 'ulan', 'sore malam mati daerah komplek tni al juanda susah', 'keluar', 'komplek tni al juanda sore tidak ada sekolah kantor', 'kebraon mati tidak ada informasi sm tugas', 'pagi pdam kebraon gang sekolah mati baik gang tomat kebraon pagi mati debit kecil mohon ada baik wilayah pokok tekan kurang pagi mati', 'tidak keluar mati tandon tip', 'pdam daerah jiwa mati', 'hubung telepon wib siang tidak ada tugas', 'senin tanggal oktober tugas pdam ganti meter ganti meter gerak kran tutup lokasi kedung baruk rungkut', 'ada tugas baik pipa bocor lokasi', 'pagi pdam pdam gayung kebonsari pagi tidak keluar alir siang mohon informasi bantu', 'kerja', 'jadwal catat mandiri tanggal ubah pikir pergi kota', 'telepon no sibuk', 'terang proses cepat kumpul berkas tanggal september ada pasang', 'kirim pesan', 'daftar daring via aplikasi tahap verifikasi pasang butuh', 'pekan pdam kunjung rumah istri tangan no surat tidak ada apa informasi janji to ganti meter has to be jadwal meter not until pekan no informasi layan mohon cek maksud jalan has tidak ada apa to do layan do butuh informasi mohon via messenger', 'nomor antri mohon bantu', 'daerah jalan gresik mati pdam mohon tindak ada', 'pdam mati wilayah rumah pondok maritim ada pemberitahuan tidur mati anak kerja sekolah butuh mandi', 'pagi mati area wisma lidah kulon', 'nyala', 'nyala', 'admin area dupak keluar chat tangki ada respon', 'telepon call center respon adu rusa meter', 'ada', 'proyek', 'anjir', 'pdam jalan raya sambikerep mati', 'ada pemberitahuan antisipasi lupa tidak ada pemberitahuan', 'informasi', 'keren instalasi ipam ngagel', 'keren olah ipam ngagel', 'dang ipam ngagel keren', 'baik', 'perumda minum populer', 'maju layan', 'keren', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'lahir to be bangga besar as indonesia', 'alir semangat muda', 'sumpah pemuda', 'sumpah pemuda', 'bangga pemuda indonesia', 'sumpah pemuda', 'sumpah pemuda cermin berani anak bangsa satu  ...
#   Keywords: mati(0.327)
#
# Cluster 3  (1 members)
#   Members: ['admin bicara baik nyata nang keluar bablas tetes kran buka pagi berangkat kerja pulang kerja bak ku kosong']
#   Keywords: admin(1.000), bablas(1.000), baik(1.000), bak(1.000), berangkat(1.000), bicara(1.000), buka(1.000), keluar(1.000), kerja(1.000), kosong(1.000)
#
# Cluster 4  (1 members)
#   Members: ['pdam hormat mohon baik debit kali mati baik tidak keluar keluar bu bayang posisi tidak tandon ganggu aktivasi rumah tangga hari']
#   Keywords: aktivasi(1.000), baik(1.000), bayang(1.000), bu(1.000), debit(1.000), ganggu(1.000), hari(1.000), hormat(1.000), kali(1.000), keluar(1.000)
#
# Cluster 5  (1 members)
#   Members: ['rumah griya surabaya asri gorong-gorong mati ape umbah umbah seragam pasang pikir ada pompa butek mati awak bayar duduk subsidi']
#   Keywords: ada(1.000), ape(1.000), asri(1.000), awak(1.000), bayar(1.000), butek(1.000), duduk(1.000), gorong-gorong(1.000), griya(1.000), mati(1.000)
#
# Cluster 6  (1 members)
#   Members: ['daerah jalan kaum gang masak sabtu minggu mati keluar lapor call center ada tugas periksa tidak minggu pagi mohon perhati']
#   Keywords: ada(1.000), call(1.000), center(1.000), daerah(1.000), gang(1.000), jalan(1.000), kaum(1.000), keluar(1.000), lapor(1.000), masak(1.000)
#
# Cluster 7  (1 members)
#   Members: ['bu kayak gorong-gorong kerja area tanggal beres perhati ada proyek gali mesti bocor kayak paham situbada karingan pipa jarak']
#   Keywords: ada(1.000), area(1.000), beres(1.000), bocor(1.000), bu(1.000), gali(1.000), gorong-gorong(1.000), jarak(1.000), karingan(1.000), kayak(1.000)
#
# Cluster 8  (1 members)
#   Members: ['anak buang beli galon ada ge tandon cebok ge shalat butuh wudhu ra tau mandi awak lengket mok tayamum']
#   Keywords: ada(1.000), anak(1.000), awak(1.000), beli(1.000), buang(1.000), butuh(1.000), cebok(1.000), galon(1.000), ge(1.000), lengket(1.000)
#
# Cluster 9  (1 members)
#   Members: ['admin telepon call center sibuk pdam surabaya panas nyala daerah tambak mayor barat telat bayat denda atur komplain respon']
#   Keywords: admin(1.000), atur(1.000), barat(1.000), bayat(1.000), call(1.000), center(1.000), daerah(1.000), denda(1.000), komplain(1.000), mayor(1.000)
#
# Cluster 10  (1 members)
#   Members: ['urus kampung rt bantu warga alami stop kran posisi buka tidak keluar sangkut aju keluh adu via wa pdam']
#   Keywords: adu(1.000), aju(1.000), alami(1.000), bantu(1.000), buka(1.000), kampung(1.000), keluar(1.000), keluh(1.000), kran(1.000), pdam(1.000)
#
# Cluster 11  (1 members)
#   Members: ['wilayah bronggalan keluar da pagi sd malam sd tahun mohon solusi lapor tugas alir cek pdam surabaya perhati daerah lancar ada']
#   Keywords: ada(1.000), alir(1.000), bronggalan(1.000), cek(1.000), da(1.000), daerah(1.000), keluar(1.000), lancar(1.000), lapor(1.000), malam(1.000)
#
# Cluster 12  (1 members)
#   Members: ['lapor pdam gara-gara jumat malam nyala ak paksa tidur hawa panas badan lengket nyala langsung mandi isi bak cuci subuh ape tidur bos']
#   Keywords: ak(1.000), ape(1.000), badan(1.000), bak(1.000), bos(1.000), cuci(1.000), gara-gara(1.000), hawa(1.000), isi(1.000), jumat(1.000)
#
# Cluster 13  (1 members)
#   Members: ['pdam hebat kl ada lambat bayar cepat putus alir langgan bikin langgan bingung dg alir ada pemberitahuan nomor warga taman telaga bodas karangrejo gajahmungkur semarang']
#   Keywords: ada(1.000), alir(1.000), bayar(1.000), bikin(1.000), bingung(1.000), bodas(1.000), cepat(1.000), dg(1.000), gajahmungkur(1.000), hebat(1.000)
#
# Cluster 14  (1 members)
#   Members: ['japri lapang langsung capek kotak culvert mohon bantu ikut cepet diare puyeng mati omset umkm dampak langgan rugi bayar tagih pdam dpt maksimal']
#   Keywords: bantu(1.000), bayar(1.000), capek(1.000), cepet(1.000), culvert(1.000), dampak(1.000), diare(1.000), dpt(1.000), ikut(1.000), japri(1.000)
#
# Cluster 15  (1 members)
#   Members: ['keluar humas ada baik sosialisasi sosial media ikut pdam sosialisasi dampak ksi solusi water tank komen sm tetangga jalan angkut orang tua mohon bijak']
#   Keywords: ada(1.000), angkut(1.000), baik(1.000), bijak(1.000), dampak(1.000), humas(1.000), ikut(1.000), jalan(1.000), keluar(1.000), komen(1.000)
#
# Cluster 16  (1 members)
#   Members: ['proyek pemkot area bocor bego seberang alfamart kerja pegawai beda area sat set hati jarang ada bocor pipa titik mohon warga rugi tutup usaha omset parah']
#   Keywords: ada(1.000), alfamart(1.000), area(1.000), beda(1.000), bego(1.000), bocor(1.000), hati(1.000), jarang(1.000), kerja(1.000), mohon(1.000)

# %%
for ver_name, res in v_results.items():
    v_ratio = res['v_ratio']
    sil     = res['sil']
    k_list  = res['k_list']
    k_curv  = res['k_curv']
    k_sil   = res['k_sil']
    Z       = res['Z']
    vec     = res['vec']
    valley_k= res['valley_k']
    best_k  = res['best_k']

    fig, axes = plt.subplots(1, 1, figsize=(12, 6))
    fig.suptitle(ver_name, fontsize=15, fontweight='bold')

    axes.plot(k_list, v_ratio, 'bo-', linewidth=2, markersize=3)
    axes.set_title("Valley tracing")
    if valley_k:
        for vk in valley_k:
            axes.axvline(vk, color='orange', linestyle=':', alpha=0.6)
        axes.axvline(best_k, color='red', linestyle='--', label=f"optimal k={best_k}")
    axes.legend()

    plt.tight_layout()
    plt.show()

    # PCA vis
    if best_k is not None:
        k_optimal  = k_curv
        labels_opt = fcluster(Z, t=k_optimal, criterion='maxclust')
        pca        = PCA(n_components=2)
        vec2d      = pca.fit_transform(vec)

# %% [markdown]
# Other versions & sehnanigans

# %%
# import matplotlib.pyplot as plt
# from scipy.cluster.hierarchy import linkage, fcluster
# from sklearn.metrics import silhouette_score
# from sklearn.decomposition import PCA
# from scipy.ndimage import gaussian_filter1d

# VERSIONS = {
#     # "Before Normalization":              vectors_dense_old,
#     "After Normalization (Threshold)":   vectors_scene_1,
#     "After Normalization (Ground 1)":    vectors_scene_2,
# }

# v_results = {}

# for ver_name, vec in VERSIONS.items():
#     print(f"\n{'='*60}")
#     print(f"Running Clsutering for: {ver_name}  |  shape: {vec.shape}")
#     print('-'*60)

#     N = vec.shape[0] - 1
#     Z = linkage(vec, method='centroid', metric='euclidean')
#     k_list = list(range(N, 1, -1))

#     grand_mean = vec.mean(axis=0)

#     sil       = []
#     vw_list   = []
#     vb_list   = []
#     v_ratio   = []
#     valley_k = []
#     valley_diff = []


#     for k in k_list:
#         labels          = fcluster(Z, t=k, criterion='maxclust')
#         unique_clusters = np.unique(labels)

#         delta_within  = 0.0
#         delta_between = 0.0

#         for cid in unique_clusters:
#             pts = vec[labels == cid]
#             ni  = pts.shape[0]
#             if ni <= 1:
#                 continue

#             centroid  = pts.mean(axis=0)
#             delta_sq  = np.sum(np.linalg.norm(pts - centroid, axis=1) ** 2) / (ni - 1)
#             delta_within  += (ni - 1) * delta_sq
#             delta_between += ni * np.linalg.norm(centroid - grand_mean) ** 2

#         vw2 = delta_within  / (N - k) if (N - k) > 0 else np.nan
#         vb2 = delta_between / (k - 1) if (k - 1) > 0 else np.nan

#         vw_list.append(vw2)
#         vb_list.append(vb2)
#         v_ratio.append((vw2 / vb2) * 100 if (vb2 and vb2 > 0) else np.nan)

#         sc = (silhouette_score(vec, labels, metric='euclidean')
#               if len(unique_clusters) >= 2 else np.nan)
#         sil.append(sc)

#     vw_list = np.array(vw_list)
#     vb_list = np.array(vb_list)
#     v_ratio = np.array(v_ratio)
#     sil     = np.array(sil)

#     # Optimal k curvature V-Ratio
#     first      = np.diff(v_ratio)
#     second     = np.diff(first)
#     idx_curv   = np.nanargmax(np.abs(second))
#     k_curv     = k_list[idx_curv + 2]

#     # Optimal k Silhouette
#     valid_idx = np.where(~np.isnan(sil))[0]
#     k_sil     = k_list[valid_idx[np.nanargmax(sil[valid_idx])]] if len(valid_idx) else None

#     print("Optimal K :")

#     for i in range(1, len(v_ratio) - 1):
#         prev = v_ratio[i - 1]
#         curr = v_ratio[i]
#         nxt  = v_ratio[i + 1]

#         if np.isnan(prev) or np.isnan(curr) or np.isnan(nxt):
#             continue
        
#         # (V_{i-1} >= V_i) ∩ (V_{i+1} > V_i)
#         if prev >= curr and nxt > curr:
#             valley_k.append(k_list[i])
#             # ∂ = (V_{i-1} + V_{i+1}) - 2V_i
#             partial_diff = (prev + nxt) - (2 * curr)
#             valley_diff.append(partial_diff)

#     print("Valley-tracing candidate k values:", valley_k)

#     # 
#     if valley_k:
#         # # calculate accuracy from ppt
#         paired = sorted(zip(valley_diff, valley_k), reverse=True)

#         max_diff    = paired[0][0]
#         max_k       = paired[0][1]

#         if len(paired) >= 2:
#             second_diff = paired[1][0]
#             second_k    = paired[1][1]
#             accuracy    = max_diff / second_diff if second_diff != 0 else float('inf')

#             print(f"Best k by valley-tracing:  {max_k}")
#             print(f"k Closest Value to max ∂:  {second_k}")
#             print(f"Max ∂:                     {max_diff:.4f}")
#             print(f"Second Max ∂:              {second_diff:.4f}")
#             print(f"Accuracy:                  {accuracy:.4f}")
#         else:
#             print(f"Only one valley found — k: {max_k}, ∂: {max_diff:.4f}")
#             print("Accuracy cannot be computed with a single valley.")
#     v_results[ver_name] = {
#         'Z': Z, 'vec': vec, 'k_list': k_list,
#         'v_ratio': v_ratio, 'sil': sil,
#         'k_curv': k_curv, 'k_sil': k_sil,
#         'valley_k': valley_k,
#         'valley_diff': max_diff,
#     }

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# data_partial['processed_text'] = data_partial['text'].apply(
#     lambda tokens: " ".join(tokens)
# )
# # data_partial['processed_text'] = data_partial['text'].apply(lambda tokens: " ".join(tokens))
# data_partial = data_partial[data_partial['processed_text'].str.strip() != ""]
# vectorizer = CountVectorizer(
#     ngram_range=(1, 1),
#     min_df=0.01,
#     max_df=0.95,
#     tokenizer=str.split
# )
# vectors = vectorizer.fit_transform(data_partial['processed_text'])
# feature_names = vectorizer.get_feature_names_out()
# vectors_dense = vectors.toarray()

# %%
# PROTECTED_WORDS = [
#     'sememi'
# ]

# factory = StemmerFactory()
# base_stemmer = factory.create_stemmer()

# existing_words = list(base_stemmer.getDictionary().getWords())
# combined_words = list(set(existing_words + PROTECTED_WORDS))
# custom_dict = ArrayDictionary(combined_words)

# stemmer = Stemmer(custom_dict)

# def stem_tokens(tokens):
#     if not isinstance(tokens, list):
#         return tokens
#     return [stemmer.stem(tok) for tok in tokens]

# data_partial["text"] = data_partial["text"].apply(stem_tokens)

# %%
# min_tokens = 3

# data_filtered = data_partial[data_partial["token_count"] >= min_tokens].copy()
# print(f"Removed {len(data_partial) - len(data_filtered)} short documents")
# print(f"Remaining: {len(data_filtered)} documents")

# %%
# def show_clusters_k(res, k, ver_name, feature_map):
#     print(f"\n{'='*60}")
#     print(f"Showing clusters at k = {k}  |  {ver_name}")
    
#     labels = fcluster(res['Z'], t=k, criterion='maxclust')
    
#     display_culster_details(
#         tfidf_matrix=res['vec'],
#         feature_names=feature_map.get(ver_name, feature_names),
#         labels=labels,
#         k=k,
#         ver_name=f"{ver_name} (k={k})"
#     )
# show_clusters_k(v_results["After Normalization (Threshold)"], 101,
#                    "After Normalization (Threshold)", feature_map)

# %%
# ## WCSS CALCULATION WITH MULTIPLE VECTOR NORMALIZATION SCENARIOS
# import matplotlib.pyplot as plt
# from scipy.cluster.hierarchy import linkage, fcluster
# from sklearn.metrics import silhouette_score
# from sklearn.decomposition import PCA

# VERSIONS = {
#     "Befor Normalization": vectors_dense_old,
#     "After Normalization (Threshold)":  vectors_scene_1,
#     "After Normalization (ground 1)":  vectors_scene_2,
# }
# N = vectors_dense_old.shape[0]-1
# k_list = list(range(N, 1, -1))

# results = {}

# for ver_name, vec in VERSIONS.items():
#     print(f"\n{'='*60}")
#     print(f"Running HAC for: {ver_name}  |  shape: {vec.shape}")
#     print('-'*60)

#     Z = linkage(vec, method='centroid', metric='euclidean')

#     wcss, sil = [], []
#     for k in k_list:
#         labels = fcluster(Z, t=k, criterion='maxclust')

#         # WCSS
#         total_var = 0.0
#         for cid in np.unique(labels):
#             pts = vec[labels == cid]
#             if pts.shape[0] <= 1:
#                 continue
#             cent = pts.mean(axis=0)
#             total_var += np.sum(np.linalg.norm(pts - cent, axis=1) ** 2)
#         wcss.append(total_var)

#         # Sil
#         if len(np.unique(labels)) >= 2:
#             sc = silhouette_score(vec, labels, metric='euclidean')
#         else:
#             sc = np.nan
#         sil.append(sc)

#     wcss = np.array(wcss)
#     sil  = np.array(sil)

#     first  = np.diff(wcss)
#     second = np.diff(first)
#     idx_curv = np.nanargmax(np.abs(second))
#     k_curv = k_list[idx_curv + 2]

#     valid_idx = np.where(~np.isnan(sil))[0]
#     k_sil = k_list[valid_idx[np.nanargmax(sil[valid_idx])]] if len(valid_idx) else None

#     print(f"Optimal K — WCSS Curvature: {k_curv}  |  Silhouette Max: {k_sil}")
#     results[ver_name] = {
#         'Z': Z, 'vec': vec, 'wcss': wcss, 'sil': sil,
#         'k_curv': k_curv, 'k_sil': k_sil
#     }

# for ver_name, res in results.items():
#     wcss   = res['wcss']
#     sil    = res['sil']
#     k_curv = res['k_curv']
#     k_sil  = res['k_sil']
#     Z      = res['Z']
#     vec    = res['vec']
#     second = np.diff(np.diff(wcss))

#     fig, axes = plt.subplots(3, 1, figsize=(12, 18))
#     fig.suptitle(ver_name, fontsize=15, fontweight='bold')

#     axes[0].plot(k_list, wcss, 'bo-', linewidth=1.5, markersize=3)
#     axes[0].axvline(k_curv, color='red', linestyle='--', label=f"k={k_curv}")
#     axes[0].set_title("WCSS vs Number of Clusters")
#     axes[0].set_xlabel("k"); axes[0].set_ylabel("WCSS")
#     axes[0].grid(alpha=0.3); axes[0].legend()

#     axes[1].plot(k_list[2:], np.abs(second), 'ro-', linewidth=1.5, markersize=3)
#     axes[1].axvline(k_curv, color='blue', linestyle='--', label=f"k={k_curv}")
#     axes[1].set_title("WCSS Curvature (Second Derivative)")
#     axes[1].set_xlabel("k"); axes[1].set_ylabel("|d²(WCSS)/dk²|")
#     axes[1].grid(alpha=0.3); axes[1].legend()

#     axes[2].plot(k_list, sil, 'go-', linewidth=1.5, markersize=3)
#     if k_sil:
#         axes[2].axvline(k_sil, color='black', linestyle='--', label=f"k={k_sil}")
#     axes[2].set_title("Silhouette Score vs k")
#     axes[2].set_xlabel("k"); axes[2].set_ylabel("Silhouette")
#     axes[2].grid(alpha=0.3); axes[2].legend()

#     plt.tight_layout()
#     plt.show()

#     k_optimal = k_curv
#     labels_opt = fcluster(Z, t=k_optimal, criterion='maxclust')
#     pca  = PCA(n_components=2)
#     vec2d = pca.fit_transform(vec)

#     plt.figure(figsize=(10, 7))
#     plt.scatter(vec2d[:, 0], vec2d[:, 1], c=labels_opt, cmap='tab20', s=15)
#     plt.title(f"PCA Visualisation — {ver_name}  (k={k_optimal})")
#     plt.xlabel("PC1"); plt.ylabel("PC2")
#     plt.grid(alpha=0.3)
#     plt.show()

# %%
# feature_map = {
#     "Before Normalization": feature_names,
#     "After Normalization (Threshold)": feature_names_scene_1,
#     "After Normalization (ground 1)": feature_names_scene_2,
# }

# def display_culster_details(tfidf_matrix, feature_names, labels, k, ver_name=""):
#     print(f"\n{'-'*30}")
#     print(f"Cluster Details — {ver_name}  (k={k})")
    
#     cluster_info = {}
    
#     for cluster_id in range(0, k):
#         indices = np.where(labels == cluster_id)[0]
        
#         if len(indices) == 0:
#             continue
        
#         cluster_data = tfidf_matrix[indices]
#         if hasattr(cluster_data, 'toarray'):
#             cluster_data = cluster_data.toarray()
#         cluster_mean = cluster_data.mean(axis=0)
#         threshold = cluster_mean.max() / 2
#         above_threshold = np.where(cluster_mean > threshold)[0]
#         sorted_idx = above_threshold[np.argsort(-cluster_mean[above_threshold])]
#         keywords = [(feature_names[i], cluster_mean[i]) for i in sorted_idx]
        
#         cluster_info[cluster_id] = {
#             'members': data_partial['processed_text'].iloc[indices].tolist(),
#             'count': len(indices),
#             'keywords': keywords
#         }
    
#     for cluster_id, info in cluster_info.items():
#         print(f"\nCluster {cluster_id}  ({info['count']} members)")
#         print(f"  Members: {info['members']}")
#         kw_str = ", ".join([f"{w}({s:.3f})" for w, s in info['keywords'][:10]])
#         print(f"  Keywords: {kw_str if kw_str else '—'}")
    
#     return cluster_info


# for ver_name, res in results.items():
#     labels_opt = fcluster(res['Z'], t=res['k_curv'], criterion='maxclust')
#     display_culster_details(
#         tfidf_matrix=res['vec'],
#         feature_names=feature_map.get(ver_name, feature_names),
#         labels=labels_opt,
#         k=res['k_curv'],
#         ver_name=ver_name
#     )

# %%
# ## V RATIO CALCULATION WITH MULTIPLE VECTOR NORMALIZATION SCENARIOS
# import matplotlib.pyplot as plt
# from scipy.cluster.hierarchy import linkage, fcluster
# from sklearn.metrics import silhouette_score
# from sklearn.decomposition import PCA

# VERSIONS = {
#     # "Before Normalization":              vectors_dense_old,
#     "After Normalization (Threshold)":   vectors_scene_1,
#     "After Normalization (Ground 1)":    vectors_scene_2,
# }

# v_results = {}

# for ver_name, vec in VERSIONS.items():
#     print(f"\n{'='*60}")
#     print(f"Running V-Ratio for: {ver_name}  |  shape: {vec.shape}")
#     print('-'*60)

#     N = vec.shape[0] - 1
#     Z = linkage(vec, method='centroid', metric='euclidean')
#     k_list = list(range(N, 1, -1))

#     grand_mean = vec.mean(axis=0)

#     sil       = []
#     vw_list   = []
#     vb_list   = []
#     v_ratio   = []
#     valley_k = []


#     for k in k_list:
#         labels          = fcluster(Z, t=k, criterion='maxclust')
#         unique_clusters = np.unique(labels)

#         delta_within  = 0.0
#         delta_between = 0.0

#         for cid in unique_clusters:
#             pts = vec[labels == cid]
#             ni  = pts.shape[0]
#             if ni <= 1:
#                 continue

#             centroid  = pts.mean(axis=0)
#             delta_sq  = np.sum(np.linalg.norm(pts - centroid, axis=1) ** 2) / (ni - 1)
#             delta_within  += (ni - 1) * delta_sq
#             delta_between += ni * np.linalg.norm(centroid - grand_mean) ** 2

#         vw2 = delta_within  / (N - k) if (N - k) > 0 else np.nan
#         vb2 = delta_between / (k - 1) if (k - 1) > 0 else np.nan

#         vw_list.append(vw2)
#         vb_list.append(vb2)
#         v_ratio.append((vw2 / vb2) * 100 if (vb2 and vb2 > 0) else np.nan)

#         sc = (silhouette_score(vec, labels, metric='euclidean')
#               if len(unique_clusters) >= 2 else np.nan)
#         sil.append(sc)

#     vw_list = np.array(vw_list)
#     vb_list = np.array(vb_list)
#     v_ratio = np.array(v_ratio)
#     sil     = np.array(sil)

#     # Optimal k via curvature of V-Ratio
#     first      = np.diff(v_ratio)
#     second     = np.diff(first)
#     idx_curv   = np.nanargmax(np.abs(second))
#     k_curv     = k_list[idx_curv + 2]

#     # Optimal k via Silhouette
#     valid_idx = np.where(~np.isnan(sil))[0]
#     k_sil     = k_list[valid_idx[np.nanargmax(sil[valid_idx])]] if len(valid_idx) else None

#     print(f"Optimal K — V-Ratio Curvature: {k_curv}  |  Silhouette Max: {k_sil}")


#     for i in range(1, len(v_ratio) - 1):
#         prev = v_ratio[i - 1]
#         curr = v_ratio[i]
#         nxt  = v_ratio[i + 1]
        
#         # skip if any are nan
#         if np.isnan(prev) or np.isnan(curr) or np.isnan(nxt):
#             continue
        
#         # paper eq (7): (V_{i-1} >= V_i) ∩ (V_{i+1} > V_i)
#         if prev >= curr and nxt > curr:
#             valley_k.append(k_list[i])

#     print("Valley-tracing candidate k values:", valley_k)

#     # global optimum is the valley with the lowest v_ratio value 4now
#     # sld probs reconfirm
#     if valley_k:
#         best_k = min(valley_k, key=lambda k: v_ratio[k_list.index(k)])
#         print(f"Best k by valley-tracing: {best_k}")
#     v_results[ver_name] = {
#         'Z': Z, 'vec': vec, 'k_list': k_list,
#         'v_ratio': v_ratio, 'sil': sil,
#         'k_curv': k_curv, 'k_sil': k_sil,
#         'valley_k': valley_k
#     }

# for ver_name, res in v_results.items():
#     v_ratio = res['v_ratio']
#     sil     = res['sil']
#     k_list  = res['k_list']
#     k_curv  = res['k_curv']
#     k_sil   = res['k_sil']
#     Z       = res['Z']
#     vec     = res['vec']

#     fig, axes = plt.subplots(2, 1, figsize=(12, 12))
#     fig.suptitle(ver_name, fontsize=15, fontweight='bold')

#     axes[0].plot(k_list, v_ratio, 'bo-', linewidth=2, markersize=3)
#     # axes[0].axvline(k_curv, color='red', linestyle='--', label=f"k={k_curv}")
#     # axes[0].set_title("V-Ratio (vw²/vb²) vs k")
#     # axes[0].set_xlabel("k"); axes[0].set_ylabel("V (%)")
#     # axes[0].grid(alpha=0.3); 
#     axes[0].legend()
#     if valley_k:
#         for vk in valley_k:
#             axes[0].axvline(vk, color='orange', linestyle=':', alpha=0.6, label=f"valley k={vk}")
#         axes[0].axvline(best_k, color='red', linestyle='--', label=f"best k={best_k}")
#     # axes[0].legend()

#     axes[1].plot(k_list, sil, 'go-', linewidth=2, markersize=3)
#     if k_sil:
#         axes[1].axvline(k_sil, color='black', linestyle='--', label=f"k={k_sil}")
#     axes[1].set_title("Silhouette Score vs k")
#     axes[1].set_xlabel("k"); axes[1].set_ylabel("Silhouette")
#     axes[1].grid(alpha=0.3); axes[1].legend()

#     plt.tight_layout()
#     plt.show()

#     # PCA visualisation at optimal k
#     k_optimal  = k_curv
#     labels_opt = fcluster(Z, t=k_optimal, criterion='maxclust')
#     pca        = PCA(n_components=2)
#     vec2d      = pca.fit_transform(vec)

#     plt.figure(figsize=(10, 7))
#     plt.scatter(vec2d[:, 0], vec2d[:, 1], c=labels_opt, cmap='tab20', s=15)
#     plt.title(f"PCA Visualisation — {ver_name}  (k={k_optimal})")
#     plt.xlabel("PC1"); plt.ylabel("PC2")
#     plt.grid(alpha=0.3)
#     plt.show()

# %% [markdown]
# visualisation

# %%
# def simple_keyword(tfidf_matrix, feature_names, labels, k):
#     cluster_keywords = {}
    
#     for cluster_id in range(1, k + 1):
#         indices = np.where(labels == cluster_id)[0]
        
#         if len(indices) == 0:
#             cluster_keywords[cluster_id] = []
#             continue

#         cluster_data = tfidf_matrix[indices]

#         if hasattr(cluster_data, 'toarray'):
#             cluster_data = cluster_data.toarray()

#         cluster_mean = cluster_data.mean(axis=0)
#         threshold = cluster_mean.max() / 2
#         above_threshold = np.where(cluster_mean > threshold)[0]
#         sorted_idx = above_threshold[np.argsort(-cluster_mean[above_threshold])]
        
#         keywords = [(feature_names[i], cluster_mean[i]) for i in sorted_idx]
#         cluster_keywords[cluster_id] = keywords
    
#     return cluster_keywords

# keywords = simple_keyword(vectors_dense, feature_names, labels_opt, k_optimal)

# for cluster_id in range(1, min(k_optimal + 1, N)):
#     if cluster_id in keywords and keywords[cluster_id]:
#         print(f"\nCluster {cluster_id}:")
#         for word, score in keywords[cluster_id][:10]:
#             print(f"  {word}: {score:.3f}")

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# data_filtered['processed_text'] = data_partial['text'].apply(
#     lambda tokens: " ".join(tokens)
# )
# data_filtered = data_filtered[data_filtered['processed_text'].str.strip() != ""]
# vectorizer = TfidfVectorizer(
#     tokenizer=str.split,
#     ngram_range=(1,1),
#     min_df=5,
#     max_df=0.95,
#     use_idf=False,
#     norm=None
# )

# vectors = vectorizer.fit_transform(data_filtered['processed_text'])
# feature_names = vectorizer.get_feature_names_out()
# vectors_dense = vectors.toarray()

# print(f"Vector shape: {vectors.shape}")
# print(f"nonzero: {vectors.nnz}")
# row = vectors[1]
# indices = row.indices
# values = row.data

# for i, v in zip(indices, values):
#     print(feature_names[i], v) 


# vectors = vectorizer.fit_transform(data_filtered['processed_text'])
# feature_names = vectorizer.get_feature_names_out()
# vectors_dense = vectors.toarray()

# vectors_dense_old = vectors_dense.copy()
# df_old = pd.DataFrame(vectors_dense_old, columns=feature_names)
# df_old.insert(0, 'comment', data_filtered['processed_text'].values)
# df_old.to_csv("test_before_normalization.csv", index=False)
# print(f"Old vector shape: {vectors_dense_old.shape}")

# vectors_scene_1 = vectors_dense.copy()

# for i in range(vectors_scene_1.shape[0]):
#     row = vectors_scene_1[i]
#     max_val = row.max()

#     if max_val == 0:
#         continue

#     threshold = max_val / 2
#     vectors_scene_1[i] = np.where(row >= threshold, row, 0.0)

# non_zero_cols = np.any(vectors_scene_1 != 0, axis=0)
# vectors_scene_1 = vectors_scene_1[:, non_zero_cols]
# feature_names_scene_1 = feature_names[non_zero_cols]

# print(f"New vector shape: {vectors_scene_1.shape}")
# print(f"Features removed: {vectors_dense.shape[1] - vectors_scene_1.shape[1]}")

# df_new = pd.DataFrame(vectors_scene_1, columns=feature_names_scene_1)
# df_new.insert(0, 'comment', data_filtered['processed_text'].values)
# df_new.to_csv("test_after_normalization.csv", index=False)

# print("Saved: tfidf_before_normalization.csv and tfidf_after_normalization.csv")

# %%
# import matplotlib.pyplot as plt
# from scipy.cluster.hierarchy import linkage, fcluster
# from sklearn.metrics import silhouette_score
# from sklearn.decomposition import PCA

# VERSIONS = {
#     "Befor Normalization": vectors_dense_old,
#     "After Normalization":  vectors_scene_1,
# }
# N = vectors_dense_old.shape[0]-1
# k_list = list(range(N, 1, -1))

# results = {}

# for ver_name, vec in VERSIONS.items():
#     print(f"\n{'='*60}")
#     print(f"Running HAC for: {ver_name}  |  shape: {vec.shape}")
#     print('-'*60)

#     Z = linkage(vec, method='centroid', metric='euclidean')

#     wcss, sil = [], []
#     for k in k_list:
#         labels = fcluster(Z, t=k, criterion='maxclust')

#         # WCSS
#         total_var = 0.0
#         for cid in np.unique(labels):
#             pts = vec[labels == cid]
#             if pts.shape[0] <= 1:
#                 continue
#             cent = pts.mean(axis=0)
#             total_var += np.sum(np.linalg.norm(pts - cent, axis=1) ** 2)
#         wcss.append(total_var)

#         # Sil
#         if len(np.unique(labels)) >= 2:
#             sc = silhouette_score(vec, labels, metric='euclidean')
#         else:
#             sc = np.nan
#         sil.append(sc)

#     wcss = np.array(wcss)
#     sil  = np.array(sil)

#     first  = np.diff(wcss)
#     second = np.diff(first)
#     idx_curv = np.nanargmax(np.abs(second))
#     k_curv = k_list[idx_curv + 2]

#     valid_idx = np.where(~np.isnan(sil))[0]
#     k_sil = k_list[valid_idx[np.nanargmax(sil[valid_idx])]] if len(valid_idx) else None

#     print(f"Optimal K — WCSS Curvature: {k_curv}  |  Silhouette Max: {k_sil}")
#     results[ver_name] = {
#         'Z': Z, 'vec': vec, 'wcss': wcss, 'sil': sil,
#         'k_curv': k_curv, 'k_sil': k_sil
#     }

# for ver_name, res in results.items():
#     wcss   = res['wcss']
#     sil    = res['sil']
#     k_curv = res['k_curv']
#     k_sil  = res['k_sil']
#     Z      = res['Z']
#     vec    = res['vec']
#     second = np.diff(np.diff(wcss))

#     fig, axes = plt.subplots(3, 1, figsize=(12, 18))
#     fig.suptitle(ver_name, fontsize=15, fontweight='bold')

#     axes[0].plot(k_list, wcss, 'bo-', linewidth=1.5, markersize=3)
#     axes[0].axvline(k_curv, color='red', linestyle='--', label=f"k={k_curv}")
#     axes[0].set_title("WCSS vs Number of Clusters")
#     axes[0].set_xlabel("k"); axes[0].set_ylabel("WCSS")
#     axes[0].grid(alpha=0.3); axes[0].legend()

#     axes[1].plot(k_list[2:], np.abs(second), 'ro-', linewidth=1.5, markersize=3)
#     axes[1].axvline(k_curv, color='blue', linestyle='--', label=f"k={k_curv}")
#     axes[1].set_title("WCSS Curvature (Second Derivative)")
#     axes[1].set_xlabel("k"); axes[1].set_ylabel("|d²(WCSS)/dk²|")
#     axes[1].grid(alpha=0.3); axes[1].legend()

#     axes[2].plot(k_list, sil, 'go-', linewidth=1.5, markersize=3)
#     if k_sil:
#         axes[2].axvline(k_sil, color='black', linestyle='--', label=f"k={k_sil}")
#     axes[2].set_title("Silhouette Score vs k")
#     axes[2].set_xlabel("k"); axes[2].set_ylabel("Silhouette")
#     axes[2].grid(alpha=0.3); axes[2].legend()

#     plt.tight_layout()
#     plt.show()

#     k_optimal = k_curv
#     labels_opt = fcluster(Z, t=k_optimal, criterion='maxclust')
#     pca  = PCA(n_components=2)
#     vec2d = pca.fit_transform(vec)

#     plt.figure(figsize=(10, 7))
#     plt.scatter(vec2d[:, 0], vec2d[:, 1], c=labels_opt, cmap='tab20', s=15)
#     plt.title(f"PCA Visualisation — {ver_name}  (k={k_optimal})")
#     plt.xlabel("PC1"); plt.ylabel("PC2")
#     plt.grid(alpha=0.3)
#     plt.show()

# %%
# def display_culster_details(tfidf_matrix, feature_names, labels, k, ver_name=""):
#     print(f"\n{'-'*30}")
#     print(f"Cluster Details — {ver_name}  (k={k})")
    
#     cluster_info = {}
    
#     for cluster_id in range(0, k):
#         indices = np.where(labels == cluster_id)[0]
        
#         if len(indices) == 0:
#             continue
        
#         cluster_data = tfidf_matrix[indices]
#         if hasattr(cluster_data, 'toarray'):
#             cluster_data = cluster_data.toarray()
#         cluster_mean = cluster_data.mean(axis=0)
#         threshold = cluster_mean.max() / 2
#         above_threshold = np.where(cluster_mean > threshold)[0]
#         sorted_idx = above_threshold[np.argsort(-cluster_mean[above_threshold])]
#         keywords = [(feature_names[i], cluster_mean[i]) for i in sorted_idx]
        
#         cluster_info[cluster_id] = {
#             'members': data_partial['processed_text'].iloc[indices].tolist(),
#             'count': len(indices),
#             'keywords': keywords
#         }
    
#     for cluster_id, info in cluster_info.items():
#         print(f"\nCluster {cluster_id}  ({info['count']} members)")
#         print(f"  Members: {info['members']}")
#         kw_str = ", ".join([f"{w}({s:.3f})" for w, s in info['keywords'][:10]])
#         print(f"  Keywords: {kw_str if kw_str else '—'}")
    
#     return cluster_info


# for ver_name, res in results.items():
#     labels_opt = fcluster(res['Z'], t=res['k_curv'], criterion='maxclust')
#     display_culster_details(
#         tfidf_matrix=res['vec'],
#         feature_names=(feature_names if ver_name == "Before Normalization" else feature_names_scene_1),
#         labels=labels_opt,
#         k=res['k_curv'],
#         ver_name=ver_name
#     )
